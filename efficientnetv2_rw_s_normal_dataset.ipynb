# %% [markdown]
# <a href="https://colab.research.google.com/github/By0ungJoo/dacon/blob/main/efficientnetv2_rw_s_normal_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install timm
import timm
model = timm.create_model('efficientnetv2_rw_s', pretrained=True, num_classes=88)
# Out:
# Collecting timm
#   Downloading timm-0.5.4-py3-none-any.whl (431 kB)
#      |████████████████████████████████| 431 kB 16.3 MB/s
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from timm) (0.12.0+cu113)
# Requirement already satisfied: torch>=1.4 in /usr/local/lib/python3.7/dist-packages (from timm) (1.11.0+cu113)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.4->timm) (4.2.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torchvision->timm) (2.23.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision->timm) (7.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torchvision->timm) (1.21.6)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision->timm) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision->timm) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision->timm) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision->timm) (2021.10.8)
# Installing collected packages: timm
# Successfully installed timm-0.5.4
# Downloading: "https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-weights/efficientnet_v2s_ra2_288-a6477665.pth" to /root/.cache/torch/hub/checkpoints/efficientnet_v2s_ra2_288-a6477665.pth

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import warnings
warnings.filterwarnings('ignore')

import torch
from glob import glob
from tqdm import tqdm
import cv2
#import timm
from torch.utils.data import Dataset, DataLoader
from sklearn.metrics import f1_score, accuracy_score
import gc
import pandas as pd
import numpy as np
import json
from PIL import Image
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
from torchvision import transforms, datasets
import matplotlib.pyplot as plt
import time
import os
import copy
import random
from sklearn.model_selection import train_test_split
from torch.utils.data import Subset
from PIL import Image

# %%
## 기본 설정
device = torch.device('cuda')
batch_size  = 32
random_seed = 1234
img_size = 224
random.seed(random_seed)
torch.manual_seed(random_seed)

# %%
def img_load(path):
    img = cv2.imread(path)[:,:,::-1] # Return type:	numpy.ndarray / 기본적으로 BGR로 불러옴, RGB 변환함
    img = cv2.resize(img, (224, 224))
    return img

class Custom_dataset_1(Dataset): # 기본
    def __init__(self, img_paths, labels, mode='train'):
        self.img_paths = img_paths
        self.labels = labels
        self.mode = mode
    def __len__(self):
        return len(self.img_paths)
    def __getitem__(self, idx):
        img = self.img_paths[idx]
        img = transforms.ToTensor()(img) # PIL or ndarray -> tensor
        if self.mode == 'train':
          img = transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])(img)
        if self.mode=='test':
          pass
        ## 레이블 > 원-핫 인코딩 하기 
        label = self.labels[idx]# (원핫인코딩 안할거면 해당 코드만 필요)
        return img, label

# %%
### 이미지 로드 및 전처리
# 이미지 경로
# train_png = sorted(glob('/content/drive/MyDrive/dacon/dacon/open/train1/*.png'))
# train_imgs = [img_load(m) for m in tqdm(train_png)]

# #train_imgs = np.load('/content/drive/MyDrive/DACON_이상치 탐지 알고리즘 경진대회/train_imgs_224.npy')
# train_y = pd.read_csv('/content/drive/MyDrive/dacon/dacon/open/train_df.csv')

# train_labels = train_y["label"] # 레이블순서는 이미지 파일 순서대로임

# label_unique = sorted(np.unique(train_labels))
# label_unique = {key:value for key,value in zip(label_unique, range(len(label_unique)))} # 오름차순으로 레이블별로 숫자 부여(0부터 시작)

# train_labels = [label_unique[k] for k in train_labels]

## 이미지 증량 시만 사용
# train_imgs = train_imgs + train_imgs
# train_labels = train_labels+train_labels

train_dataset = Custom_dataset_1(np.array(train_imgs), np.array(train_labels), mode='train')

### 데이터셋 분리 > 층화추출 & 테스터 데이터 비율 : 0.3, 시드 : 1234, 셔플 = True(default)
train_idx, vaild_idx = train_test_split(list(range(len(train_dataset))), stratify=train_labels, test_size=0.3, random_state=random_seed)

datasets = {} # 데이터셋을 담을 딕셔너리
datasets['train'] = Subset(train_dataset, train_idx)
datasets['vaild']  = Subset(train_dataset, vaild_idx)

## data loader 선언
dataloaders, batch_num = {}, {}
dataloaders['train'] = torch.utils.data.DataLoader(datasets['train'],
                                                  batch_size=batch_size, shuffle=True,
                                                  num_workers=0)
dataloaders['vaild']  = torch.utils.data.DataLoader(datasets['vaild'],
                                                    batch_size=batch_size, shuffle=False,
                                                    num_workers=0)
'''
데이터 변형 코드를 추가한 후 아래 오류코드가 나와
Caught TypeError in DataLoader worker process 0
DataLoader > num_workers 를 4 -> 0 로 낮춤
'''

batch_num['train'], batch_num['vaild'] = len(dataloaders['train']), len(dataloaders['vaild'])
print('batch_size : %d,  train/vaild(데이터셋개수/배치사이즈) : %d / %d' % (batch_size, batch_num['train'],batch_num['vaild']))
# Out:
# batch_size : 32,  train/vaild(데이터셋개수/배치사이즈) : 94 / 41

# %%
import gc
gc.collect()
torch.cuda.empty_cache()

### f1 스코어 함수 
def score_function(real, pred): # 라이브러리 > sklearn.metrics 
    score = f1_score(real, pred, average="macro")
    return score

def train_model(model, criterion, optimizer, scheduler, num_epochs=25):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0
    #train_loss, train_acc, valid_loss, valid_acc = [], [], [], []
    train_loss, train_acc, valid_loss, valid_acc, train_f1, valid_f1 = [], [], [], [], [], []
    
    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs))# - 1))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'vaild']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss, running_corrects, num_cnt = 0.0, 0, 0
            
            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device) # device = torch.device('cuda')
                labels = labels.to(device) # device = torch.device('cuda')

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
                num_cnt += len(labels)
            if phase == 'train':
                scheduler.step()
            
            epoch_loss = float(running_loss / num_cnt)
            epoch_acc  = float((running_corrects.double() / num_cnt).cpu()*100)
            f1 = score_function(labels.cpu().data, preds.cpu()) # score_function or f1_score

            if phase == 'train':
                train_loss.append(epoch_loss)
                train_acc.append(epoch_acc)
                train_f1.append(f1)
            else:
                valid_loss.append(epoch_loss)
                valid_acc.append(epoch_acc)
                valid_f1.append(f1)

            print('{} Loss: {:.5f} Acc: {:.5f} macro-f1: {:.5f}'.format(phase, epoch_loss, epoch_acc, f1))
           
            # deep copy the model(최적모델 저장)
            if phase == 'vaild' and epoch_acc > best_acc:
                best_idx = epoch
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())
#                 best_model_wts = copy.deepcopy(model.module.state_dict())
                print('==> best model saved - %d / %.1f'%(best_idx, best_acc))
        # 한 에포크마다 실행 시간 출력하기(누적 시간으로 출력됨)
        time_elapsed = time.time() - since
        print('each epochs training time : {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))
        print('\n')

        # 한 에포크마다 필요없는 메모리 지우기 : 지우기 효과는 아직 확인 못해봄
        try:      
          gc.collect() # cpu 비움
          torch.cuda.empty_cache() # gpu 비움
        except:
          pass
          
    ## 학습 마무리 후
    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))
    print('Best valid Acc: %d - %.1f' %(best_idx, best_acc))

    # load best model weights
    '''
    한 에포크 마다 저장된 최적의 모델 가중치로 조정 후 다음 에포크가 돌아감
    '''
    model.load_state_dict(best_model_wts)
    torch.save(model.state_dict(), 'president_model1.pt')
    print('model saved')
    return model, best_idx, best_acc, train_loss, train_acc, valid_loss, valid_acc, train_f1, valid_f1

# 설정
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")  # set gpu

model = model.to(device)

criterion = nn.CrossEntropyLoss()

optimizer_ft = optim.SGD(model.parameters(), 
                         lr = 0.05,
                         momentum=0.9,
                         weight_decay=1e-4)

lmbda = lambda epoch: 0.98739
exp_lr_scheduler = optim.lr_scheduler.MultiplicativeLR(optimizer_ft, lr_lambda=lmbda)

# 사전학습된 가중치와 모델을 가져와 데이터셋으로 추가 모델 학습
model, best_idx, best_acc, train_loss, train_acc, valid_loss, valid_acc, train_f1, valid_f1 = train_model(model, criterion, optimizer_ft, exp_lr_scheduler, num_epochs=100)
# Out:
# Epoch 0/100
# ----------
# train Loss: 1.10321 Acc: 81.38991 macro-f1: 0.89610
# vaild Loss: 0.69216 Acc: 84.96885 macro-f1: 1.00000
# ==> best model saved - 0 / 85.0
# each epochs training time : 0m 43s
#
#
# Epoch 1/100
# ----------
# train Loss: 0.54444 Acc: 87.00301 macro-f1: 0.83333
# vaild Loss: 0.59622 Acc: 87.38318 macro-f1: 0.50000
# ==> best model saved - 1 / 87.4
# each epochs training time : 1m 26s
#
#
# Epoch 2/100
# ----------
# train Loss: 0.42715 Acc: 89.50885 macro-f1: 0.74510
# vaild Loss: 0.42740 Acc: 89.87539 macro-f1: 1.00000
# ==> best model saved - 2 / 89.9
# each epochs training time : 2m 11s
#
#
# Epoch 3/100
# ----------
# train Loss: 0.31481 Acc: 91.74741 macro-f1: 0.67619
# vaild Loss: 0.45717 Acc: 90.49844 macro-f1: 1.00000
# ==> best model saved - 3 / 90.5
# each epochs training time : 2m 56s
#
#
# Epoch 4/100
# ----------
# train Loss: 0.23421 Acc: 93.75209 macro-f1: 0.81905
# vaild Loss: 0.40033 Acc: 91.51090 macro-f1: 1.00000
# ==> best model saved - 4 / 91.5
# each epochs training time : 3m 41s
#
#
# Epoch 5/100
# ----------
# train Loss: 0.18931 Acc: 94.85466 macro-f1: 1.00000
# vaild Loss: 0.40637 Acc: 91.19938 macro-f1: 1.00000
# each epochs training time : 4m 26s
#
#
# Epoch 6/100
# ----------
# train Loss: 0.14141 Acc: 95.99064 macro-f1: 0.81818
# vaild Loss: 0.41485 Acc: 91.97819 macro-f1: 1.00000
# ==> best model saved - 6 / 92.0
# each epochs training time : 5m 11s
#
#
# Epoch 7/100
# ----------
# train Loss: 0.12502 Acc: 96.65887 macro-f1: 1.00000
# vaild Loss: 0.37717 Acc: 91.97819 macro-f1: 1.00000
# each epochs training time : 5m 56s
#
#
# Epoch 8/100
# ----------
# train Loss: 0.07580 Acc: 97.99532 macro-f1: 1.00000
# vaild Loss: 0.43905 Acc: 90.65421 macro-f1: 0.66667
# each epochs training time : 6m 41s
#
#
# Epoch 9/100
# ----------
# train Loss: 0.05484 Acc: 98.56331 macro-f1: 1.00000
# vaild Loss: 0.36844 Acc: 92.44548 macro-f1: 0.66667
# ==> best model saved - 9 / 92.4
# each epochs training time : 7m 26s
#
#
# Epoch 10/100
# ----------
# train Loss: 0.04165 Acc: 98.73037 macro-f1: 1.00000
# vaild Loss: 0.38939 Acc: 91.82243 macro-f1: 1.00000
# each epochs training time : 8m 11s
#
#
# Epoch 11/100
# ----------
# train Loss: 0.02518 Acc: 99.33177 macro-f1: 0.88889
# vaild Loss: 0.36641 Acc: 92.60125 macro-f1: 1.00000
# ==> best model saved - 11 / 92.6
# each epochs training time : 8m 56s
#
#
# Epoch 12/100
# ----------
# train Loss: 0.02888 Acc: 99.13131 macro-f1: 1.00000
# vaild Loss: 0.38854 Acc: 92.13396 macro-f1: 1.00000
# each epochs training time : 9m 41s
#
#
# Epoch 13/100
# ----------
# train Loss: 0.05102 Acc: 98.66355 macro-f1: 1.00000
# vaild Loss: 0.34753 Acc: 92.91277 macro-f1: 1.00000
# ==> best model saved - 13 / 92.9
# each epochs training time : 10m 25s
#
#
# Epoch 14/100
# ----------
# train Loss: 0.03589 Acc: 99.03107 macro-f1: 1.00000
# vaild Loss: 0.35543 Acc: 93.06854 macro-f1: 1.00000
# ==> best model saved - 14 / 93.1
# each epochs training time : 11m 10s
#
#
# Epoch 15/100
# ----------
# train Loss: 0.01978 Acc: 99.63248 macro-f1: 1.00000
# vaild Loss: 0.33031 Acc: 93.53583 macro-f1: 1.00000
# ==> best model saved - 15 / 93.5
# each epochs training time : 11m 55s
#
#
# Epoch 16/100
# ----------
# train Loss: 0.00894 Acc: 99.79953 macro-f1: 1.00000
# vaild Loss: 0.36076 Acc: 93.76947 macro-f1: 1.00000
# ==> best model saved - 16 / 93.8
# each epochs training time : 12m 40s
#
#
# Epoch 17/100
# ----------
# train Loss: 0.02441 Acc: 99.39860 macro-f1: 1.00000
# vaild Loss: 0.39803 Acc: 92.67913 macro-f1: 1.00000
# each epochs training time : 13m 25s
#
#
# Epoch 18/100
# ----------
# train Loss: 0.02084 Acc: 99.53224 macro-f1: 1.00000
# vaild Loss: 0.39679 Acc: 92.52336 macro-f1: 1.00000
# each epochs training time : 14m 10s
#
#
# Epoch 19/100
# ----------
# train Loss: 0.01046 Acc: 99.79953 macro-f1: 1.00000
# vaild Loss: 0.39703 Acc: 92.75701 macro-f1: 1.00000
# each epochs training time : 14m 55s
#
#
# Epoch 20/100
# ----------
# train Loss: 0.00639 Acc: 99.83294 macro-f1: 1.00000
# vaild Loss: 0.39801 Acc: 93.30218 macro-f1: 1.00000
# each epochs training time : 15m 40s
#
#
# Epoch 21/100
# ----------
# train Loss: 0.01121 Acc: 99.63248 macro-f1: 1.00000
# vaild Loss: 0.35786 Acc: 92.75701 macro-f1: 1.00000
# each epochs training time : 16m 25s
#
#
# Epoch 22/100
# ----------
# train Loss: 0.00986 Acc: 99.76612 macro-f1: 1.00000
# vaild Loss: 0.41993 Acc: 92.21184 macro-f1: 1.00000
# each epochs training time : 17m 10s
#
#
# Epoch 23/100
# ----------
# train Loss: 0.00208 Acc: 99.96659 macro-f1: 1.00000
# vaild Loss: 0.39567 Acc: 93.45794 macro-f1: 1.00000
# each epochs training time : 17m 55s
#
#
# Epoch 24/100
# ----------
# train Loss: 0.00241 Acc: 99.96659 macro-f1: 1.00000
# vaild Loss: 0.40281 Acc: 93.53583 macro-f1: 1.00000
# each epochs training time : 18m 40s
#
#
# Epoch 25/100
# ----------
# train Loss: 0.00741 Acc: 99.83294 macro-f1: 1.00000
# vaild Loss: 0.42661 Acc: 92.91277 macro-f1: 1.00000
# each epochs training time : 19m 25s
#
#
# Epoch 26/100
# ----------
# train Loss: 0.00266 Acc: 99.96659 macro-f1: 1.00000
# vaild Loss: 0.43287 Acc: 92.99065 macro-f1: 1.00000
# each epochs training time : 20m 10s
#
#
# Epoch 27/100
# ----------
# train Loss: 0.00647 Acc: 99.89977 macro-f1: 1.00000
# vaild Loss: 0.46754 Acc: 92.52336 macro-f1: 1.00000
# each epochs training time : 20m 55s
#
#
# Epoch 28/100
# ----------
# train Loss: 0.00748 Acc: 99.79953 macro-f1: 1.00000
# vaild Loss: 0.41888 Acc: 92.60125 macro-f1: 1.00000
# each epochs training time : 21m 40s
#
#
# Epoch 29/100
# ----------
# train Loss: 0.00598 Acc: 99.79953 macro-f1: 1.00000
# vaild Loss: 0.40540 Acc: 92.52336 macro-f1: 1.00000
# each epochs training time : 22m 24s
#
#
# Epoch 30/100
# ----------
# train Loss: 0.02089 Acc: 99.56565 macro-f1: 1.00000
# vaild Loss: 0.40088 Acc: 92.75701 macro-f1: 1.00000
# each epochs training time : 23m 9s
#
#
# Epoch 31/100
# ----------
# train Loss: 0.00526 Acc: 99.86635 macro-f1: 1.00000
# vaild Loss: 0.39743 Acc: 92.99065 macro-f1: 1.00000
# each epochs training time : 23m 54s
#
#
# Epoch 32/100
# ----------
# train Loss: 0.00625 Acc: 99.79953 macro-f1: 1.00000
# vaild Loss: 0.39688 Acc: 92.91277 macro-f1: 1.00000
# each epochs training time : 24m 39s
#
#
# Epoch 33/100
# ----------
# train Loss: 0.00186 Acc: 99.93318 macro-f1: 1.00000
# vaild Loss: 0.40831 Acc: 92.52336 macro-f1: 1.00000
# each epochs training time : 25m 24s
#
#
# Epoch 34/100
# ----------
# train Loss: 0.00079 Acc: 100.00000 macro-f1: 1.00000
# vaild Loss: 0.42180 Acc: 92.83489 macro-f1: 1.00000
# each epochs training time : 26m 9s
#
#
# Epoch 35/100
# ----------
# train Loss: 0.00146 Acc: 99.96659 macro-f1: 1.00000
# vaild Loss: 0.42776 Acc: 92.83489 macro-f1: 1.00000
# each epochs training time : 26m 54s
#
#
# Epoch 36/100
# ----------
# train Loss: 0.00064 Acc: 100.00000 macro-f1: 1.00000
# vaild Loss: 0.41120 Acc: 92.99065 macro-f1: 1.00000
# each epochs training time : 27m 38s
#
#
# Epoch 37/100
# ----------
# train Loss: 0.00051 Acc: 100.00000 macro-f1: 1.00000
# vaild Loss: 0.42422 Acc: 92.75701 macro-f1: 1.00000
# each epochs training time : 28m 23s
#
#
# Epoch 38/100
# ----------
# train Loss: 0.00040 Acc: 100.00000 macro-f1: 1.00000
# vaild Loss: 0.41596 Acc: 92.75701 macro-f1: 1.00000
# each epochs training time : 29m 8s
#
#
# Epoch 39/100
# ----------
# train Loss: 0.00044 Acc: 100.00000 macro-f1: 1.00000
# vaild Loss: 0.42413 Acc: 93.06854 macro-f1: 1.00000
# each epochs training time : 29m 53s
#
#
# Epoch 40/100
# ----------
# train Loss: 0.00036 Acc: 100.00000 macro-f1: 1.00000
# vaild Loss: 0.42605 Acc: 92.99065 macro-f1: 1.00000
# each epochs training time : 30m 38s
#
#
# Epoch 41/100
# ----------
# train Loss: 0.00046 Acc: 100.00000 macro-f1: 1.00000
# vaild Loss: 0.43472 Acc: 93.06854 macro-f1: 1.00000
# each epochs training time : 31m 23s
#
#
# Epoch 42/100
# ----------
# train Loss: 0.00029 Acc: 100.00000 macro-f1: 1.00000
# vaild Loss: 0.44603 Acc: 92.60125 macro-f1: 1.00000
# each epochs training time : 32m 8s
#
#
# Epoch 43/100
# ----------
# train Loss: 0.00035 Acc: 100.00000 macro-f1: 1.00000
# vaild Loss: 0.44055 Acc: 93.06854 macro-f1: 1.00000
# each epochs training time : 32m 53s
#
#
# Epoch 44/100
# ----------
# train Loss: 0.00038 Acc: 100.00000 macro-f1: 1.00000
# vaild Loss: 0.43173 Acc: 92.83489 macro-f1: 1.00000
# each epochs training time : 33m 37s
#
#
# Epoch 45/100
# ----------
# train Loss: 0.00027 Acc: 100.00000 macro-f1: 1.00000
# vaild Loss: 0.43367 Acc: 92.99065 macro-f1: 1.00000
# each epochs training time : 34m 22s
#
#
# Epoch 46/100
# ----------
# train Loss: 0.00029 Acc: 100.00000 macro-f1: 1.00000
# vaild Loss: 0.44617 Acc: 92.91277 macro-f1: 1.00000
# each epochs training time : 35m 7s
#
#
# Epoch 47/100
# ----------
# train Loss: 0.00033 Acc: 100.00000 macro-f1: 1.00000
# vaild Loss: 0.43802 Acc: 92.91277 macro-f1: 1.00000
# each epochs training time : 35m 52s
#
#
# Epoch 48/100
# ----------
# train Loss: 0.00031 Acc: 100.00000 macro-f1: 1.00000
# vaild Loss: 0.43982 Acc: 92.83489 macro-f1: 1.00000
# each epochs training time : 36m 37s
#
#
# Epoch 49/100
# ----------
# train Loss: 0.00026 Acc: 100.00000 macro-f1: 1.00000
# vaild Loss: 0.43714 Acc: 92.75701 macro-f1: 1.00000
# each epochs training time : 37m 22s
#
#
# Epoch 50/100
# ----------
# train Loss: 0.00031 Acc: 100.00000 macro-f1: 1.00000
# vaild Loss: 0.44067 Acc: 92.83489 macro-f1: 1.00000
# each epochs training time : 38m 7s
#
#
# Epoch 51/100
# ----------
# train Loss: 0.00026 Acc: 100.00000 macro-f1: 1.00000
# vaild Loss: 0.44458 Acc: 92.75701 macro-f1: 1.00000
# each epochs training time : 38m 52s
#
#
# Epoch 52/100
# ----------
# train Loss: 0.00034 Acc: 100.00000 macro-f1: 1.00000
# vaild Loss: 0.43301 Acc: 93.14642 macro-f1: 1.00000
# each epochs training time : 39m 37s
#
#
# Epoch 53/100
# ----------
# train Loss: 0.00027 Acc: 100.00000 macro-f1: 1.00000
# vaild Loss: 0.43776 Acc: 92.99065 macro-f1: 1.00000
# each epochs training time : 40m 21s
#
#
# Epoch 54/100
# ----------
# train Loss: 0.00025 Acc: 100.00000 macro-f1: 1.00000
# vaild Loss: 0.44197 Acc: 92.83489 macro-f1: 1.00000
# each epochs training time : 41m 6s
#
#
# Epoch 55/100
# ----------
# train Loss: 0.00030 Acc: 100.00000 macro-f1: 1.00000
# vaild Loss: 0.44943 Acc: 92.75701 macro-f1: 1.00000
# each epochs training time : 41m 51s
#
#
# Epoch 56/100
# ----------
# train Loss: 0.00041 Acc: 100.00000 macro-f1: 1.00000
# vaild Loss: 0.45029 Acc: 92.28972 macro-f1: 1.00000
# each epochs training time : 42m 36s
#
#
# Epoch 57/100
# ----------
# train Loss: 0.00031 Acc: 100.00000 macro-f1: 1.00000
# vaild Loss: 0.46033 Acc: 92.83489 macro-f1: 1.00000
# each epochs training time : 43m 21s
#
#
# Epoch 58/100
# ----------
# train Loss: 0.00041 Acc: 100.00000 macro-f1: 1.00000
# vaild Loss: 0.43231 Acc: 92.75701 macro-f1: 1.00000
# each epochs training time : 44m 6s
#
#
# Epoch 59/100
# ----------
# train Loss: 0.00034 Acc: 100.00000 macro-f1: 1.00000
# vaild Loss: 0.43142 Acc: 92.83489 macro-f1: 1.00000
# each epochs training time : 44m 51s
#
#
# Epoch 60/100
# ----------
# train Loss: 0.00036 Acc: 100.00000 macro-f1: 1.00000
# vaild Loss: 0.45104 Acc: 92.36760 macro-f1: 1.00000
# each epochs training time : 45m 36s
#
#
# Epoch 61/100
# ----------
# train Loss: 0.00028 Acc: 100.00000 macro-f1: 1.00000
# vaild Loss: 0.46162 Acc: 92.60125 macro-f1: 1.00000
# each epochs training time : 46m 20s
#
#
# Epoch 62/100
# ----------
# train Loss: 0.00028 Acc: 100.00000 macro-f1: 1.00000
# vaild Loss: 0.45619 Acc: 92.67913 macro-f1: 1.00000
# each epochs training time : 47m 5s
#
#
# Epoch 63/100
# ----------
# train Loss: 0.00033 Acc: 100.00000 macro-f1: 1.00000
# vaild Loss: 0.45459 Acc: 92.52336 macro-f1: 1.00000
# each epochs training time : 47m 50s
#
#
# Epoch 64/100
# ----------
# train Loss: 0.00031 Acc: 100.00000 macro-f1: 1.00000
# vaild Loss: 0.44642 Acc: 92.75701 macro-f1: 1.00000
# each epochs training time : 48m 35s
#
#
# Epoch 65/100
# ----------
# train Loss: 0.00026 Acc: 100.00000 macro-f1: 1.00000
# vaild Loss: 0.46080 Acc: 92.44548 macro-f1: 1.00000
# each epochs training time : 49m 20s
#
#
# Epoch 66/100
# ----------
# train Loss: 0.00028 Acc: 100.00000 macro-f1: 1.00000
# vaild Loss: 0.44681 Acc: 92.60125 macro-f1: 1.00000
# each epochs training time : 50m 5s
#
#
# Epoch 67/100
# ----------
# train Loss: 0.00030 Acc: 100.00000 macro-f1: 1.00000
# vaild Loss: 0.43622 Acc: 92.67913 macro-f1: 1.00000
# each epochs training time : 50m 49s
#
#
# Epoch 68/100
# ----------
# train Loss: 0.00024 Acc: 100.00000 macro-f1: 1.00000
# vaild Loss: 0.45021 Acc: 92.44548 macro-f1: 1.00000
# each epochs training time : 51m 34s
#
#
# Epoch 69/100
# ----------
# train Loss: 0.00027 Acc: 100.00000 macro-f1: 1.00000
# vaild Loss: 0.45780 Acc: 92.13396 macro-f1: 1.00000
# each epochs training time : 52m 19s
#
#
# Epoch 70/100
# ----------
# train Loss: 0.00032 Acc: 100.00000 macro-f1: 1.00000
# vaild Loss: 0.45469 Acc: 92.52336 macro-f1: 1.00000
# each epochs training time : 53m 4s
#
#
# Epoch 71/100
# ----------
# train Loss: 0.00025 Acc: 100.00000 macro-f1: 1.00000
# vaild Loss: 0.45601 Acc: 92.67913 macro-f1: 1.00000
# each epochs training time : 53m 49s
#
#
# Epoch 72/100
# ----------
# train Loss: 0.00037 Acc: 100.00000 macro-f1: 1.00000
# vaild Loss: 0.46381 Acc: 92.44548 macro-f1: 1.00000
# each epochs training time : 54m 34s
#
#
# Epoch 73/100
# ----------
# train Loss: 0.00021 Acc: 100.00000 macro-f1: 1.00000
# vaild Loss: 0.45541 Acc: 92.52336 macro-f1: 1.00000
# each epochs training time : 55m 19s
#
#
# Epoch 74/100
# ----------
# train Loss: 0.00026 Acc: 100.00000 macro-f1: 1.00000
# vaild Loss: 0.45745 Acc: 92.60125 macro-f1: 1.00000
# each epochs training time : 56m 3s
#
#
# Epoch 75/100
# ----------
# train Loss: 0.00025 Acc: 100.00000 macro-f1: 1.00000
# vaild Loss: 0.45289 Acc: 92.75701 macro-f1: 1.00000
# each epochs training time : 56m 48s
#
#
# Epoch 76/100
# ----------
# train Loss: 0.00148 Acc: 99.93318 macro-f1: 1.00000
# vaild Loss: 0.46824 Acc: 92.28972 macro-f1: 1.00000
# each epochs training time : 57m 33s
#
#
# Epoch 77/100
# ----------
# train Loss: 0.00036 Acc: 100.00000 macro-f1: 1.00000
# vaild Loss: 0.47012 Acc: 92.13396 macro-f1: 1.00000
# each epochs training time : 58m 18s
#
#
# Epoch 78/100
# ----------
# train Loss: 0.00077 Acc: 100.00000 macro-f1: 1.00000
# vaild Loss: 0.46338 Acc: 92.05607 macro-f1: 1.00000
# each epochs training time : 59m 3s
#
#
# Epoch 79/100
# ----------
# train Loss: 0.00044 Acc: 100.00000 macro-f1: 1.00000
# vaild Loss: 0.46799 Acc: 92.13396 macro-f1: 1.00000
# each epochs training time : 59m 48s
#
#
# Epoch 80/100
# ----------
# train Loss: 0.00030 Acc: 100.00000 macro-f1: 1.00000
# vaild Loss: 0.46927 Acc: 92.44548 macro-f1: 1.00000
# each epochs training time : 60m 32s
#
#
# Epoch 81/100
# ----------
# train Loss: 0.00033 Acc: 100.00000 macro-f1: 1.00000
# vaild Loss: 0.45580 Acc: 92.52336 macro-f1: 1.00000
# each epochs training time : 61m 17s
#
#
# Epoch 82/100
# ----------
# train Loss: 0.00034 Acc: 100.00000 macro-f1: 1.00000
# vaild Loss: 0.47313 Acc: 91.90031 macro-f1: 1.00000
# each epochs training time : 62m 2s
#
#
# Epoch 83/100
# ----------
# train Loss: 0.00066 Acc: 100.00000 macro-f1: 1.00000
# vaild Loss: 0.46420 Acc: 92.36760 macro-f1: 1.00000
# each epochs training time : 62m 47s
#
#
# Epoch 84/100
# ----------
# train Loss: 0.00028 Acc: 100.00000 macro-f1: 1.00000
# vaild Loss: 0.45950 Acc: 92.67913 macro-f1: 1.00000
# each epochs training time : 63m 32s
#
#
# Epoch 85/100
# ----------
# train Loss: 0.00042 Acc: 100.00000 macro-f1: 1.00000
# vaild Loss: 0.46492 Acc: 92.52336 macro-f1: 1.00000
# each epochs training time : 64m 17s
#
#
# Epoch 86/100
# ----------
# train Loss: 0.00034 Acc: 100.00000 macro-f1: 1.00000
# vaild Loss: 0.46274 Acc: 92.28972 macro-f1: 1.00000
# each epochs training time : 65m 2s
#
#
# Epoch 87/100
# ----------
# train Loss: 0.00030 Acc: 100.00000 macro-f1: 1.00000
# vaild Loss: 0.46017 Acc: 92.67913 macro-f1: 1.00000
# each epochs training time : 65m 46s
#
#
# Epoch 88/100
# ----------
# train Loss: 0.00035 Acc: 100.00000 macro-f1: 1.00000
# vaild Loss: 0.45792 Acc: 92.52336 macro-f1: 1.00000
# each epochs training time : 66m 31s
#
#
# Epoch 89/100
# ----------
# train Loss: 0.00037 Acc: 100.00000 macro-f1: 1.00000
# vaild Loss: 0.46018 Acc: 92.67913 macro-f1: 1.00000
# each epochs training time : 67m 16s
#
#
# Epoch 90/100
# ----------
# train Loss: 0.00035 Acc: 100.00000 macro-f1: 1.00000
# vaild Loss: 0.46623 Acc: 92.05607 macro-f1: 1.00000
# each epochs training time : 68m 1s
#
#
# Epoch 91/100
# ----------
# train Loss: 0.00066 Acc: 100.00000 macro-f1: 1.00000
# vaild Loss: 0.44817 Acc: 92.75701 macro-f1: 1.00000
# each epochs training time : 68m 46s
#
#
# Epoch 92/100
# ----------
# train Loss: 0.00028 Acc: 100.00000 macro-f1: 1.00000
# vaild Loss: 0.47006 Acc: 91.97819 macro-f1: 1.00000
# each epochs training time : 69m 31s
#
#
# Epoch 93/100
# ----------
# train Loss: 0.00025 Acc: 100.00000 macro-f1: 1.00000
# vaild Loss: 0.46234 Acc: 92.44548 macro-f1: 1.00000
# each epochs training time : 70m 16s
#
#
# Epoch 94/100
# ----------
# train Loss: 0.00105 Acc: 99.96659 macro-f1: 1.00000
# vaild Loss: 0.46596 Acc: 92.44548 macro-f1: 1.00000
# each epochs training time : 71m 1s
#
#
# Epoch 95/100
# ----------
# train Loss: 0.00035 Acc: 100.00000 macro-f1: 1.00000
# vaild Loss: 0.46512 Acc: 92.52336 macro-f1: 1.00000
# each epochs training time : 71m 45s
#
#
# Epoch 96/100
# ----------
# train Loss: 0.00034 Acc: 100.00000 macro-f1: 1.00000
# vaild Loss: 0.46328 Acc: 92.52336 macro-f1: 1.00000
# each epochs training time : 72m 30s
#
#
# Epoch 97/100
# ----------
# train Loss: 0.00030 Acc: 100.00000 macro-f1: 1.00000
# vaild Loss: 0.46796 Acc: 92.44548 macro-f1: 1.00000
# each epochs training time : 73m 15s
#
#
# Epoch 98/100
# ----------
# train Loss: 0.00035 Acc: 100.00000 macro-f1: 1.00000
# vaild Loss: 0.45593 Acc: 92.60125 macro-f1: 1.00000
# each epochs training time : 74m 0s
#
#
# Epoch 99/100
# ----------
# train Loss: 0.00032 Acc: 100.00000 macro-f1: 1.00000
# vaild Loss: 0.47080 Acc: 92.21184 macro-f1: 1.00000
# each epochs training time : 74m 45s
#
#
# Training complete in 74m 45s
# Best valid Acc: 16 - 93.8
# model saved

# %%
## 모델을 평가 모드로 변경하고 test 데이터 분류
test_png = sorted(glob('/content/drive/MyDrive/dacon/dacon/open/test/*.png'))
test_imgs = [img_load(n) for n in tqdm(test_png)]
test_dataset = Custom_dataset_1(np.array(test_imgs), np.array(["tmp"]*len(test_imgs)), mode='test')
test_loader = DataLoader(test_dataset, shuffle=False, batch_size=batch_size)

model.eval()
f_pred = []

with torch.no_grad():
    for batch in (test_loader):
        x = torch.tensor(batch[0], dtype = torch.float32, device = device)
        with torch.cuda.amp.autocast():
            pred = model(x)
        f_pred.extend(pred.argmax(1).detach().cpu().numpy().tolist())
# Out:
# 100%|██████████| 2154/2154 [02:38<00:00, 13.60it/s]

# %%
## 숫자로된 레이블을 문자열 레이블로 변경
label_decoder = {value:key for key, value in label_unique.items()}
f_result = [label_decoder[result] for result in f_pred]

# %%
from datetime import datetime as dt 
today = dt.today().strftime('%Y-%m-%d')
version = f'efficientNetv2_rw_by_timm_imageTransfroms_ver_{today}'
submission = pd.read_csv(f"/content/drive/MyDrive/dacon/dacon/open/sample_submission.csv")

## 시각적 확인을 위해 문자열 레이블로 이루어진 된 label 필드 생성
submission["label"] = f_result
display(submission)
submission.to_csv(f"/content/drive/MyDrive/dacon/dacon/open/sample_submission_basic_{version}.csv", index = False)
# Out:
#       index            label
# 0         0     leather-good
# 1         1     leather-good
# 2         2  transistor-good
# 3         3     leather-good
# 4         4        tile-good
# ...     ...              ...
# 2149   2149     leather-good
# 2150   2150       screw-good
# 2151   2151        grid-good
# 2152   2152       cable-good
# 2153   2153      zipper-good
#
# [2154 rows x 2 columns]
