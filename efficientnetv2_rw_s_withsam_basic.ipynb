# %% [markdown]
# <a href="https://colab.research.google.com/github/By0ungJoo/dacon/blob/main/efficientnetv2_rw_s_withsam_basic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install timm
import timm
model = timm.create_model('efficientnetv2_rw_s', pretrained=True, num_classes=88)
# Out:
# Collecting timm
#   Downloading timm-0.5.4-py3-none-any.whl (431 kB)
#      |████████████████████████████████| 431 kB 9.8 MB/s
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from timm) (0.12.0+cu113)
# Requirement already satisfied: torch>=1.4 in /usr/local/lib/python3.7/dist-packages (from timm) (1.11.0+cu113)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.4->timm) (4.2.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torchvision->timm) (2.23.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torchvision->timm) (1.21.6)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision->timm) (7.1.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision->timm) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision->timm) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision->timm) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision->timm) (2.10)
# Installing collected packages: timm
# Successfully installed timm-0.5.4
# Downloading: "https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-weights/efficientnet_v2s_ra2_288-a6477665.pth" to /root/.cache/torch/hub/checkpoints/efficientnet_v2s_ra2_288-a6477665.pth

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import warnings
warnings.filterwarnings('ignore')

import torch
from glob import glob
from tqdm import tqdm
import cv2
#import timm
from torch.utils.data import Dataset, DataLoader
from sklearn.metrics import f1_score, accuracy_score
import gc
import pandas as pd
import numpy as np
import json
from PIL import Image
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
from torchvision import transforms, datasets
import matplotlib.pyplot as plt
import time
import os
import copy
import random
from sklearn.model_selection import train_test_split
from torch.utils.data import Subset
from PIL import Image

# %%
## 기본 설정
device = torch.device('cuda')
batch_size  = 32
random_seed = 1234
img_size = 224
random.seed(random_seed)
torch.manual_seed(random_seed)

# %%
def img_load(path):
    img = cv2.imread(path)[:,:,::-1] # Return type:	numpy.ndarray / 기본적으로 BGR로 불러옴, RGB 변환함
    img = cv2.resize(img, (224, 224))
    return img

class Custom_dataset_1(Dataset): # 기본
    def __init__(self, img_paths, labels, mode='train'):
        self.img_paths = img_paths
        self.labels = labels
        self.mode = mode
    def __len__(self):
        return len(self.img_paths)
    def __getitem__(self, idx):
        img = self.img_paths[idx]
        img = transforms.ToTensor()(img) # PIL or ndarray -> tensor
        if self.mode == 'train':
            img = transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])(img)
        if self.mode=='test':
            img = transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])(img)
            pass
        ## 레이블 > 원-핫 인코딩 하기 
        label = self.labels[idx]# (원핫인코딩 안할거면 해당 코드만 필요)
        return img, label

# %%
class SAM(torch.optim.Optimizer):
    def __init__(self, params, base_optimizer, rho=0.05, **kwargs):
        assert rho >= 0.0, f"Invalid rho, should be non-negative: {rho}"

        defaults = dict(rho=rho, **kwargs)
        super(SAM, self).__init__(params, defaults)

        self.base_optimizer = base_optimizer(self.param_groups, **kwargs)
        self.param_groups = self.base_optimizer.param_groups

    @torch.no_grad()
    def first_step(self, zero_grad=False):
        grad_norm = self._grad_norm()
        for group in self.param_groups:
            scale = group["rho"] / (grad_norm + 1e-12)

            for p in group["params"]:
                if p.grad is None: continue
                e_w = p.grad * scale.to(p)
                p.add_(e_w)  # climb to the local maximum "w + e(w)"
                self.state[p]["e_w"] = e_w

        if zero_grad: self.zero_grad()

    @torch.no_grad()
    def second_step(self, zero_grad=False):
        for group in self.param_groups:
            for p in group["params"]:
                if p.grad is None: continue
                p.sub_(self.state[p]["e_w"])  # get back to "w" from "w + e(w)"

        self.base_optimizer.step()  # do the actual "sharpness-aware" update

        if zero_grad: self.zero_grad()

    @torch.no_grad()
    def step(self, closure=None):
        assert closure is not None, "Sharpness Aware Minimization requires closure, but it was not provided"
        closure = torch.enable_grad()(closure)  # the closure should do a full forward-backward pass

        self.first_step(zero_grad=True)
        closure()
        self.second_step()

    def _grad_norm(self):
        shared_device = self.param_groups[0]["params"][0].device  # put everything on the same device, in case of model parallelism
        norm = torch.norm(
                    torch.stack([
                        p.grad.norm(p=2).to(shared_device)
                        for group in self.param_groups for p in group["params"]
                        if p.grad is not None
                    ]),
                    p=2
               )
        return norm

# %%
### 이미지 로드 및 전처리
# 이미지 경로
train_png = sorted(glob('/content/drive/MyDrive/dacon/dacon/open/train1/*.png'))
train_imgs = [img_load(m) for m in tqdm(train_png)]

#train_imgs = np.load('/content/drive/MyDrive/DACON_이상치 탐지 알고리즘 경진대회/train_imgs_224.npy')
train_y = pd.read_csv('/content/drive/MyDrive/dacon/dacon/open/train_df.csv')

train_labels = train_y["label"] # 레이블순서는 이미지 파일 순서대로임

label_unique = sorted(np.unique(train_labels))
label_unique = {key:value for key,value in zip(label_unique, range(len(label_unique)))} # 오름차순으로 레이블별로 숫자 부여(0부터 시작)

train_labels = [label_unique[k] for k in train_labels]

## 이미지 증량 시만 사용
# train_imgs = train_imgs + train_imgs
# train_labels = train_labels+train_labels

train_dataset = Custom_dataset_1(np.array(train_imgs), np.array(train_labels), mode='train')

### 데이터셋 분리 > 층화추출 & 테스터 데이터 비율 : 0.3, 시드 : 1234, 셔플 = True(default)
train_idx, vaild_idx = train_test_split(list(range(len(train_dataset))), stratify=train_labels, test_size=0.3, random_state=random_seed)

datasets = {} # 데이터셋을 담을 딕셔너리
datasets['train'] = Subset(train_dataset, train_idx)
datasets['vaild']  = Subset(train_dataset, vaild_idx)

## data loader 선언
dataloaders, batch_num = {}, {}
dataloaders['train'] = torch.utils.data.DataLoader(datasets['train'],
                                                  batch_size=batch_size, shuffle=True,
                                                  num_workers=0)
dataloaders['vaild']  = torch.utils.data.DataLoader(datasets['vaild'],
                                                    batch_size=batch_size, shuffle=False,
                                                    num_workers=0)
'''
데이터 변형 코드를 추가한 후 아래 오류코드가 나와
Caught TypeError in DataLoader worker process 0
DataLoader > num_workers 를 4 -> 0 로 낮춤
'''

batch_num['train'], batch_num['vaild'] = len(dataloaders['train']), len(dataloaders['vaild'])
print('batch_size : %d,  train/vaild(데이터셋개수/배치사이즈) : %d / %d' % (batch_size, batch_num['train'],batch_num['vaild']))
# Out:
# 100%|██████████| 4277/4277 [02:10<00:00, 32.88it/s]
# batch_size : 32,  train/vaild(데이터셋개수/배치사이즈) : 94 / 41

# %%
import gc
gc.collect()
torch.cuda.empty_cache()

### f1 스코어 함수 
def score_function(real, pred): # 라이브러리 > sklearn.metrics 
    score = f1_score(real, pred, average="macro")
    return score

def train_model(model, criterion, optimizer, scheduler, num_epochs=25):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0
    #train_loss, train_acc, valid_loss, valid_acc = [], [], [], []
    train_loss, train_acc, valid_loss, valid_acc, train_f1, valid_f1 = [], [], [], [], [], []
    
    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs))# - 1))
        print('-' * 10)
        train_pred=[]
        train_y=[]

        # Each epoch has a training and validation phase
        for phase in ['train', 'vaild']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss, running_corrects, num_cnt = 0.0, 0, 0
            
            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device) # device = torch.device('cuda')
                labels = labels.to(device) # device = torch.device('cuda')

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    # if phase == 'train':
                    #     loss.backward()
                    #     optimizer.step()
                     # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.first_step(zero_grad=True)
                        criterion(model(inputs), labels).backward()
                        optimizer.second_step(zero_grad=True)

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
                num_cnt += len(labels)
                train_pred += preds.detach().cpu().numpy().tolist()
                train_y += labels.detach().cpu().data.numpy().tolist() 
            if phase == 'train':
                scheduler.step()
            
            epoch_loss = float(running_loss / num_cnt)
            epoch_acc  = float((running_corrects.double() / num_cnt).cpu()*100)
            # f1 = score_function(labels.cpu().data, preds.cpu()) # score_function or f1_score
            f1 = score_function(train_y,  train_pred) 
            
            if phase == 'train':
                train_loss.append(epoch_loss)
                train_acc.append(epoch_acc)
                train_f1.append(f1)
            else:
                valid_loss.append(epoch_loss)
                valid_acc.append(epoch_acc)
                valid_f1.append(f1)

            print('{} Loss: {:.5f} Acc: {:.5f} macro-f1: {:.5f}'.format(phase, epoch_loss, epoch_acc, f1))
           
            # deep copy the model(최적모델 저장)
            if phase == 'vaild' and epoch_acc > best_acc:
                best_idx = epoch
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())
#                 best_model_wts = copy.deepcopy(model.module.state_dict())
                print('==> best model saved - %d / %.1f'%(best_idx, best_acc))
        # 한 에포크마다 실행 시간 출력하기(누적 시간으로 출력됨)
        time_elapsed = time.time() - since
        print('each epochs training time : {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))
        print('\n')

        # 한 에포크마다 필요없는 메모리 지우기 : 지우기 효과는 아직 확인 못해봄
        try:      
          gc.collect() # cpu 비움
          torch.cuda.empty_cache() # gpu 비움
        except:
          pass
          
    ## 학습 마무리 후
    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))
    print('Best valid Acc: %d - %.1f' %(best_idx, best_acc))

    # load best model weights
    '''
    한 에포크 마다 저장된 최적의 모델 가중치로 조정 후 다음 에포크가 돌아감
    '''
    model.load_state_dict(best_model_wts)
    torch.save(model.state_dict(), '/content/drive/MyDrive/dacon/dacon/model/president_model.pt')
    print('model saved')
    return model, best_idx, best_acc, train_loss, train_acc, valid_loss, valid_acc, train_f1, valid_f1

# 설정
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")  # set gpu

model = model.to(device)

criterion = nn.CrossEntropyLoss()

# optimizer_ft = optim.SGD(model.parameters(), 
#                          lr = 0.05,
#                          momentum=0.9,
#                          weight_decay=1e-4)

base_optimizer = torch.optim.SGD
optimizer_ft = SAM(model.parameters(), base_optimizer, lr=0.001, momentum=0.9)
lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer_ft,
                                                step_size = 5,
                                                gamma = 0.75)

lmbda = lambda epoch: 0.98739
exp_lr_scheduler = optim.lr_scheduler.MultiplicativeLR(optimizer_ft, lr_lambda=lmbda)

# 사전학습된 가중치와 모델을 가져와 데이터셋으로 추가 모델 학습
model, best_idx, best_acc, train_loss, train_acc, valid_loss, valid_acc, train_f1, valid_f1 = train_model(model, criterion, optimizer_ft, exp_lr_scheduler, num_epochs=100)
# Out:
# Epoch 0/100
# ----------
# train Loss: 2.63237 Acc: 57.93518 macro-f1: 0.12335
# vaild Loss: 1.19287 Acc: 84.81308 macro-f1: 0.13489
# ==> best model saved - 0 / 84.8
# each epochs training time : 0m 53s
#
#
# Epoch 1/100
# ----------
# train Loss: 1.02286 Acc: 84.86468 macro-f1: 0.15606
# vaild Loss: 0.92230 Acc: 84.81308 macro-f1: 0.15615
# each epochs training time : 1m 45s
#
#
# Epoch 2/100
# ----------
# train Loss: 0.88927 Acc: 84.86468 macro-f1: 0.15616
# vaild Loss: 0.83825 Acc: 84.81308 macro-f1: 0.15619
# each epochs training time : 2m 38s
#
#
# Epoch 3/100
# ----------
# train Loss: 0.79462 Acc: 84.96492 macro-f1: 0.16768
# vaild Loss: 0.76538 Acc: 84.89097 macro-f1: 0.16576
# ==> best model saved - 3 / 84.9
# each epochs training time : 3m 31s
#
#
# Epoch 4/100
# ----------
# train Loss: 0.72935 Acc: 85.09856 macro-f1: 0.17633
# vaild Loss: 0.71649 Acc: 85.04673 macro-f1: 0.17594
# ==> best model saved - 4 / 85.0
# each epochs training time : 4m 23s
#
#
# Epoch 5/100
# ----------
# train Loss: 0.66214 Acc: 85.26562 macro-f1: 0.18621
# vaild Loss: 0.67024 Acc: 85.20249 macro-f1: 0.18394
# ==> best model saved - 5 / 85.2
# each epochs training time : 5m 16s
#
#
# Epoch 6/100
# ----------
# train Loss: 0.60605 Acc: 85.80020 macro-f1: 0.22510
# vaild Loss: 0.63583 Acc: 85.51402 macro-f1: 0.21969
# ==> best model saved - 6 / 85.5
# each epochs training time : 6m 8s
#
#
# Epoch 7/100
# ----------
# train Loss: 0.56846 Acc: 86.30137 macro-f1: 0.25511
# vaild Loss: 0.60175 Acc: 85.59190 macro-f1: 0.24165
# ==> best model saved - 7 / 85.6
# each epochs training time : 7m 1s
#
#
# Epoch 8/100
# ----------
# train Loss: 0.53121 Acc: 86.43502 macro-f1: 0.26397
# vaild Loss: 0.59480 Acc: 85.82555 macro-f1: 0.25233
# ==> best model saved - 8 / 85.8
# each epochs training time : 7m 54s
#
#
# Epoch 9/100
# ----------
# train Loss: 0.50464 Acc: 87.27030 macro-f1: 0.32230
# vaild Loss: 0.54428 Acc: 86.44860 macro-f1: 0.30772
# ==> best model saved - 9 / 86.4
# each epochs training time : 8m 46s
#
#
# Epoch 10/100
# ----------
# train Loss: 0.46776 Acc: 87.63782 macro-f1: 0.34493
# vaild Loss: 0.52782 Acc: 86.83801 macro-f1: 0.33137
# ==> best model saved - 10 / 86.8
# each epochs training time : 9m 39s
#
#
# Epoch 11/100
# ----------
# train Loss: 0.43125 Acc: 88.43969 macro-f1: 0.39066
# vaild Loss: 0.50005 Acc: 86.99377 macro-f1: 0.36666
# ==> best model saved - 11 / 87.0
# each epochs training time : 10m 31s
#
#
# Epoch 12/100
# ----------
# train Loss: 0.40183 Acc: 88.90745 macro-f1: 0.42164
# vaild Loss: 0.47774 Acc: 86.99377 macro-f1: 0.39054
# each epochs training time : 11m 24s
#
#
# Epoch 13/100
# ----------
# train Loss: 0.38459 Acc: 89.47544 macro-f1: 0.45699
# vaild Loss: 0.47444 Acc: 87.22741 macro-f1: 0.41954
# ==> best model saved - 13 / 87.2
# each epochs training time : 12m 16s
#
#
# Epoch 14/100
# ----------
# train Loss: 0.34629 Acc: 90.51119 macro-f1: 0.52956
# vaild Loss: 0.43654 Acc: 88.08411 macro-f1: 0.48568
# ==> best model saved - 14 / 88.1
# each epochs training time : 13m 9s
#
#
# Epoch 15/100
# ----------
# train Loss: 0.33957 Acc: 90.57802 macro-f1: 0.52188
# vaild Loss: 0.43487 Acc: 87.85047 macro-f1: 0.47836
# each epochs training time : 14m 1s
#
#
# Epoch 16/100
# ----------
# train Loss: 0.31101 Acc: 91.24624 macro-f1: 0.56133
# vaild Loss: 0.41830 Acc: 88.23988 macro-f1: 0.51333
# ==> best model saved - 16 / 88.2
# each epochs training time : 14m 54s
#
#
# Epoch 17/100
# ----------
# train Loss: 0.29049 Acc: 91.64718 macro-f1: 0.57786
# vaild Loss: 0.40613 Acc: 88.47352 macro-f1: 0.53158
# ==> best model saved - 17 / 88.5
# each epochs training time : 15m 47s
#
#
# Epoch 18/100
# ----------
# train Loss: 0.27929 Acc: 92.31540 macro-f1: 0.63266
# vaild Loss: 0.39403 Acc: 88.55140 macro-f1: 0.57380
# ==> best model saved - 18 / 88.6
# each epochs training time : 16m 39s
#
#
# Epoch 19/100
# ----------
# train Loss: 0.25968 Acc: 92.51587 macro-f1: 0.63648
# vaild Loss: 0.38410 Acc: 88.70717 macro-f1: 0.57989
# ==> best model saved - 19 / 88.7
# each epochs training time : 17m 32s
#
#
# Epoch 20/100
# ----------
# train Loss: 0.24397 Acc: 93.38456 macro-f1: 0.68397
# vaild Loss: 0.37379 Acc: 89.09657 macro-f1: 0.62137
# ==> best model saved - 20 / 89.1
# each epochs training time : 18m 25s
#
#
# Epoch 21/100
# ----------
# train Loss: 0.22957 Acc: 94.28667 macro-f1: 0.74414
# vaild Loss: 0.36488 Acc: 89.56386 macro-f1: 0.67411
# ==> best model saved - 21 / 89.6
# each epochs training time : 19m 17s
#
#
# Epoch 22/100
# ----------
# train Loss: 0.21554 Acc: 94.55396 macro-f1: 0.74399
# vaild Loss: 0.34317 Acc: 89.79751 macro-f1: 0.67505
# ==> best model saved - 22 / 89.8
# each epochs training time : 20m 10s
#
#
# Epoch 23/100
# ----------
# train Loss: 0.20481 Acc: 94.88807 macro-f1: 0.76406
# vaild Loss: 0.35105 Acc: 89.87539 macro-f1: 0.69481
# ==> best model saved - 23 / 89.9
# each epochs training time : 21m 2s
#
#
# Epoch 24/100
# ----------
# train Loss: 0.19103 Acc: 95.08854 macro-f1: 0.77823
# vaild Loss: 0.33919 Acc: 89.64174 macro-f1: 0.69850
# each epochs training time : 21m 55s
#
#
# Epoch 25/100
# ----------
# train Loss: 0.18063 Acc: 95.82359 macro-f1: 0.81867
# vaild Loss: 0.34705 Acc: 90.18692 macro-f1: 0.73701
# ==> best model saved - 25 / 90.2
# each epochs training time : 22m 47s
#
#
# Epoch 26/100
# ----------
# train Loss: 0.17433 Acc: 96.09088 macro-f1: 0.83622
# vaild Loss: 0.33198 Acc: 90.42056 macro-f1: 0.75650
# ==> best model saved - 26 / 90.4
# each epochs training time : 23m 40s
#
#
# Epoch 27/100
# ----------
# train Loss: 0.17338 Acc: 95.89041 macro-f1: 0.83711
# vaild Loss: 0.33149 Acc: 90.65421 macro-f1: 0.75912
# ==> best model saved - 27 / 90.7
# each epochs training time : 24m 33s
#
#
# Epoch 28/100
# ----------
# train Loss: 0.16143 Acc: 96.62546 macro-f1: 0.86322
# vaild Loss: 0.31900 Acc: 90.57632 macro-f1: 0.77845
# each epochs training time : 25m 25s
#
#
# Epoch 29/100
# ----------
# train Loss: 0.14820 Acc: 96.69228 macro-f1: 0.86756
# vaild Loss: 0.31984 Acc: 90.42056 macro-f1: 0.78063
# each epochs training time : 26m 18s
#
#
# Epoch 30/100
# ----------
# train Loss: 0.13153 Acc: 97.32710 macro-f1: 0.89714
# vaild Loss: 0.30850 Acc: 90.57632 macro-f1: 0.80440
# each epochs training time : 27m 10s
#
#
# Epoch 31/100
# ----------
# train Loss: 0.12887 Acc: 97.56098 macro-f1: 0.90717
# vaild Loss: 0.30650 Acc: 90.88785 macro-f1: 0.81395
# ==> best model saved - 31 / 90.9
# each epochs training time : 28m 3s
#
#
# Epoch 32/100
# ----------
# train Loss: 0.12057 Acc: 97.69462 macro-f1: 0.91192
# vaild Loss: 0.30057 Acc: 90.34268 macro-f1: 0.81587
# each epochs training time : 28m 55s
#
#
# Epoch 33/100
# ----------
# train Loss: 0.11917 Acc: 97.82827 macro-f1: 0.91462
# vaild Loss: 0.29716 Acc: 90.96573 macro-f1: 0.81873
# ==> best model saved - 33 / 91.0
# each epochs training time : 29m 48s
#
#
# Epoch 34/100
# ----------
# train Loss: 0.10990 Acc: 98.32944 macro-f1: 0.94002
# vaild Loss: 0.28636 Acc: 91.19938 macro-f1: 0.84717
# ==> best model saved - 34 / 91.2
# each epochs training time : 30m 40s
#
#
# Epoch 35/100
# ----------
# train Loss: 0.10886 Acc: 98.09556 macro-f1: 0.92540
# vaild Loss: 0.30165 Acc: 90.73209 macro-f1: 0.82901
# each epochs training time : 31m 33s
#
#
# Epoch 36/100
# ----------
# train Loss: 0.10109 Acc: 98.59673 macro-f1: 0.94891
# vaild Loss: 0.27786 Acc: 91.35514 macro-f1: 0.85393
# ==> best model saved - 36 / 91.4
# each epochs training time : 32m 25s
#
#
# Epoch 37/100
# ----------
# train Loss: 0.09744 Acc: 98.46308 macro-f1: 0.94402
# vaild Loss: 0.28410 Acc: 91.43302 macro-f1: 0.85375
# ==> best model saved - 37 / 91.4
# each epochs training time : 33m 18s
#
#
# Epoch 38/100
# ----------
# train Loss: 0.08667 Acc: 99.09790 macro-f1: 0.96991
# vaild Loss: 0.28599 Acc: 91.35514 macro-f1: 0.87064
# each epochs training time : 34m 10s
#
#
# Epoch 39/100
# ----------
# train Loss: 0.08962 Acc: 98.66355 macro-f1: 0.95144
# vaild Loss: 0.28087 Acc: 91.66667 macro-f1: 0.85999
# ==> best model saved - 39 / 91.7
# each epochs training time : 35m 3s
#
#
# Epoch 40/100
# ----------
# train Loss: 0.08459 Acc: 98.93084 macro-f1: 0.95698
# vaild Loss: 0.27345 Acc: 91.82243 macro-f1: 0.86490
# ==> best model saved - 40 / 91.8
# each epochs training time : 35m 56s
#
#
# Epoch 41/100
# ----------
# train Loss: 0.08076 Acc: 98.93084 macro-f1: 0.96617
# vaild Loss: 0.28587 Acc: 91.74455 macro-f1: 0.87443
# each epochs training time : 36m 48s
#
#
# Epoch 42/100
# ----------
# train Loss: 0.07699 Acc: 99.16472 macro-f1: 0.97096
# vaild Loss: 0.28750 Acc: 91.58879 macro-f1: 0.87695
# each epochs training time : 37m 41s
#
#
# Epoch 43/100
# ----------
# train Loss: 0.07513 Acc: 99.16472 macro-f1: 0.96953
# vaild Loss: 0.27657 Acc: 91.82243 macro-f1: 0.87552
# each epochs training time : 38m 33s
#
#
# Epoch 44/100
# ----------
# train Loss: 0.07191 Acc: 99.23154 macro-f1: 0.97489
# vaild Loss: 0.26913 Acc: 91.90031 macro-f1: 0.88260
# ==> best model saved - 44 / 91.9
# each epochs training time : 39m 26s
#
#
# Epoch 45/100
# ----------
# train Loss: 0.06633 Acc: 99.36519 macro-f1: 0.97977
# vaild Loss: 0.27964 Acc: 91.27726 macro-f1: 0.87816
# each epochs training time : 40m 18s
#
#
# Epoch 46/100
# ----------
# train Loss: 0.06338 Acc: 99.19813 macro-f1: 0.97124
# vaild Loss: 0.27791 Acc: 92.28972 macro-f1: 0.88428
# ==> best model saved - 46 / 92.3
# each epochs training time : 41m 11s
#
#
# Epoch 47/100
# ----------
# train Loss: 0.06275 Acc: 99.43201 macro-f1: 0.98105
# vaild Loss: 0.27048 Acc: 91.90031 macro-f1: 0.88851
# each epochs training time : 42m 3s
#
#
# Epoch 48/100
# ----------
# train Loss: 0.06119 Acc: 99.43201 macro-f1: 0.98009
# vaild Loss: 0.26891 Acc: 92.60125 macro-f1: 0.89472
# ==> best model saved - 48 / 92.6
# each epochs training time : 42m 56s
#
#
# Epoch 49/100
# ----------
# train Loss: 0.05368 Acc: 99.59906 macro-f1: 0.98621
# vaild Loss: 0.26634 Acc: 91.90031 macro-f1: 0.89046
# each epochs training time : 43m 48s
#
#
# Epoch 50/100
# ----------
# train Loss: 0.05463 Acc: 99.69930 macro-f1: 0.98822
# vaild Loss: 0.26233 Acc: 92.21184 macro-f1: 0.89430
# each epochs training time : 44m 41s
#
#
# Epoch 51/100
# ----------
# train Loss: 0.05281 Acc: 99.59906 macro-f1: 0.98326
# vaild Loss: 0.26361 Acc: 92.05607 macro-f1: 0.88936
# each epochs training time : 45m 33s
#
#
# Epoch 52/100
# ----------
# train Loss: 0.05052 Acc: 99.63248 macro-f1: 0.98482
# vaild Loss: 0.26291 Acc: 92.21184 macro-f1: 0.89353
# each epochs training time : 46m 26s
#
#
# Epoch 53/100
# ----------
# train Loss: 0.04730 Acc: 99.69930 macro-f1: 0.98831
# vaild Loss: 0.26621 Acc: 91.90031 macro-f1: 0.89402
# each epochs training time : 47m 18s
#
#
# Epoch 54/100
# ----------
# train Loss: 0.05009 Acc: 99.53224 macro-f1: 0.98501
# vaild Loss: 0.26598 Acc: 91.90031 macro-f1: 0.88745
# each epochs training time : 48m 11s
#
#
# Epoch 55/100
# ----------
# train Loss: 0.04783 Acc: 99.66589 macro-f1: 0.99002
# vaild Loss: 0.26854 Acc: 91.97819 macro-f1: 0.89397
# each epochs training time : 49m 3s
#
#
# Epoch 56/100
# ----------
# train Loss: 0.04548 Acc: 99.76612 macro-f1: 0.99231
# vaild Loss: 0.26117 Acc: 91.82243 macro-f1: 0.89130
# each epochs training time : 49m 56s
#
#
# Epoch 57/100
# ----------
# train Loss: 0.04506 Acc: 99.76612 macro-f1: 0.99279
# vaild Loss: 0.25609 Acc: 92.36760 macro-f1: 0.90053
# each epochs training time : 50m 48s
#
#
# Epoch 58/100
# ----------
# train Loss: 0.04432 Acc: 99.63248 macro-f1: 0.98699
# vaild Loss: 0.26105 Acc: 92.52336 macro-f1: 0.89951
# each epochs training time : 51m 41s
#
#
# Epoch 59/100
# ----------
# train Loss: 0.04052 Acc: 99.69930 macro-f1: 0.99089
# vaild Loss: 0.25949 Acc: 92.28972 macro-f1: 0.89730
# each epochs training time : 52m 33s
#
#
# Epoch 60/100
# ----------
# train Loss: 0.04170 Acc: 99.83294 macro-f1: 0.99467
# vaild Loss: 0.26237 Acc: 92.28972 macro-f1: 0.90046
# each epochs training time : 53m 26s
#
#
# Epoch 61/100
# ----------
# train Loss: 0.03910 Acc: 99.83294 macro-f1: 0.99386
# vaild Loss: 0.25700 Acc: 92.44548 macro-f1: 0.90351
# each epochs training time : 54m 18s
#
#
# Epoch 62/100
# ----------
# train Loss: 0.03794 Acc: 99.86635 macro-f1: 0.99498
# vaild Loss: 0.25916 Acc: 92.60125 macro-f1: 0.90344
# each epochs training time : 55m 11s
#
#
# Epoch 63/100
# ----------
# train Loss: 0.03634 Acc: 99.86635 macro-f1: 0.99662
# vaild Loss: 0.25978 Acc: 92.21184 macro-f1: 0.90011
# each epochs training time : 56m 3s
#
#
# Epoch 64/100
# ----------
# train Loss: 0.03695 Acc: 99.69930 macro-f1: 0.99003
# vaild Loss: 0.25327 Acc: 92.99065 macro-f1: 0.90842
# ==> best model saved - 64 / 93.0
# each epochs training time : 56m 56s
#
#
# Epoch 65/100
# ----------
# train Loss: 0.03192 Acc: 99.93318 macro-f1: 0.99735
# vaild Loss: 0.24731 Acc: 92.75701 macro-f1: 0.90863
# each epochs training time : 57m 48s
#
#
# Epoch 66/100
# ----------
# train Loss: 0.03171 Acc: 99.86635 macro-f1: 0.99503
# vaild Loss: 0.25343 Acc: 92.13396 macro-f1: 0.89834
# each epochs training time : 58m 41s
#
#
# Epoch 67/100
# ----------
# train Loss: 0.03091 Acc: 99.93318 macro-f1: 0.99816
# vaild Loss: 0.24960 Acc: 92.44548 macro-f1: 0.90655
# each epochs training time : 59m 33s
#
#
# Epoch 68/100
# ----------
# train Loss: 0.03145 Acc: 99.79953 macro-f1: 0.99301
# vaild Loss: 0.25846 Acc: 92.67913 macro-f1: 0.90358
# each epochs training time : 60m 26s
#
#
# Epoch 69/100
# ----------
# train Loss: 0.02919 Acc: 99.93318 macro-f1: 0.99830
# vaild Loss: 0.25947 Acc: 92.67913 macro-f1: 0.91071
# each epochs training time : 61m 18s
#
#
# Epoch 70/100
# ----------
# train Loss: 0.03601 Acc: 99.76612 macro-f1: 0.99231
# vaild Loss: 0.25289 Acc: 92.67913 macro-f1: 0.90265
# each epochs training time : 62m 11s
#
#
# Epoch 71/100
# ----------
# train Loss: 0.02843 Acc: 99.79953 macro-f1: 0.99305
# vaild Loss: 0.25248 Acc: 92.36760 macro-f1: 0.89989
# each epochs training time : 63m 3s
#
#
# Epoch 72/100
# ----------
# train Loss: 0.03038 Acc: 99.93318 macro-f1: 0.99815
# vaild Loss: 0.24918 Acc: 92.91277 macro-f1: 0.91104
# each epochs training time : 63m 56s
#
#
# Epoch 73/100
# ----------
# train Loss: 0.02589 Acc: 99.86635 macro-f1: 0.99665
# vaild Loss: 0.25049 Acc: 92.75701 macro-f1: 0.91005
# each epochs training time : 64m 48s
#
#
# Epoch 74/100
# ----------
# train Loss: 0.02506 Acc: 99.93318 macro-f1: 0.99825
# vaild Loss: 0.25575 Acc: 92.67913 macro-f1: 0.91075
# each epochs training time : 65m 41s
#
#
# Epoch 75/100
# ----------
# train Loss: 0.02486 Acc: 99.89977 macro-f1: 0.99736
# vaild Loss: 0.24603 Acc: 92.67913 macro-f1: 0.90800
# each epochs training time : 66m 33s
#
#
# Epoch 76/100
# ----------
# train Loss: 0.02499 Acc: 99.93318 macro-f1: 0.99815
# vaild Loss: 0.25467 Acc: 92.67913 macro-f1: 0.90886
# each epochs training time : 67m 26s
#
#
# Epoch 77/100
# ----------
# train Loss: 0.02316 Acc: 99.96659 macro-f1: 0.99910
# vaild Loss: 0.24974 Acc: 92.91277 macro-f1: 0.91307
# each epochs training time : 68m 18s
#
#
# Epoch 78/100
# ----------
# train Loss: 0.02378 Acc: 99.93318 macro-f1: 0.99814
# vaild Loss: 0.24934 Acc: 92.99065 macro-f1: 0.91396
# each epochs training time : 69m 11s
#
#
# Epoch 79/100
# ----------
# train Loss: 0.02335 Acc: 99.96659 macro-f1: 0.99893
# vaild Loss: 0.25695 Acc: 92.28972 macro-f1: 0.90412
# each epochs training time : 70m 3s
#
#
# Epoch 80/100
# ----------
# train Loss: 0.02219 Acc: 99.93318 macro-f1: 0.99747
# vaild Loss: 0.25994 Acc: 92.28972 macro-f1: 0.90101
# each epochs training time : 70m 56s
#
#
# Epoch 81/100
# ----------
# train Loss: 0.02218 Acc: 99.96659 macro-f1: 0.99893
# vaild Loss: 0.25189 Acc: 92.91277 macro-f1: 0.91184
# each epochs training time : 71m 48s
#
#
# Epoch 82/100
# ----------
# train Loss: 0.02276 Acc: 99.83294 macro-f1: 0.99548
# vaild Loss: 0.25323 Acc: 93.06854 macro-f1: 0.91062
# ==> best model saved - 82 / 93.1
# each epochs training time : 72m 41s
#
#
# Epoch 83/100
# ----------
# train Loss: 0.02201 Acc: 100.00000 macro-f1: 1.00000
# vaild Loss: 0.25925 Acc: 92.28972 macro-f1: 0.90526
# each epochs training time : 73m 33s
#
#
# Epoch 84/100
# ----------
# train Loss: 0.02042 Acc: 99.93318 macro-f1: 0.99803
# vaild Loss: 0.25855 Acc: 93.06854 macro-f1: 0.91460
# each epochs training time : 74m 26s
#
#
# Epoch 85/100
# ----------
# train Loss: 0.02236 Acc: 99.96659 macro-f1: 0.99834
# vaild Loss: 0.25646 Acc: 92.67913 macro-f1: 0.90830
# each epochs training time : 75m 18s
#
#
# Epoch 86/100
# ----------
# train Loss: 0.01739 Acc: 99.96659 macro-f1: 0.99893
# vaild Loss: 0.26249 Acc: 92.44548 macro-f1: 0.90837
# each epochs training time : 76m 11s
#
#
# Epoch 87/100
# ----------
# train Loss: 0.01921 Acc: 99.93318 macro-f1: 0.99841
# vaild Loss: 0.24756 Acc: 92.75701 macro-f1: 0.90943
# each epochs training time : 77m 3s
#
#
# Epoch 88/100
# ----------
# train Loss: 0.01870 Acc: 99.96659 macro-f1: 0.99909
# vaild Loss: 0.24904 Acc: 92.83489 macro-f1: 0.91195
# each epochs training time : 77m 56s
#
#
# Epoch 89/100
# ----------
# train Loss: 0.02036 Acc: 99.93318 macro-f1: 0.99751
# vaild Loss: 0.25075 Acc: 92.83489 macro-f1: 0.90961
# each epochs training time : 78m 48s
#
#
# Epoch 90/100
# ----------
# train Loss: 0.01744 Acc: 99.96659 macro-f1: 0.99834
# vaild Loss: 0.25995 Acc: 92.75701 macro-f1: 0.90993
# each epochs training time : 79m 41s
#
#
# Epoch 91/100
# ----------
# train Loss: 0.01953 Acc: 99.89977 macro-f1: 0.99515
# vaild Loss: 0.24018 Acc: 93.06854 macro-f1: 0.90924
# each epochs training time : 80m 33s
#
#
# Epoch 92/100
# ----------
# train Loss: 0.01555 Acc: 100.00000 macro-f1: 1.00000
# vaild Loss: 0.25693 Acc: 92.67913 macro-f1: 0.90982
# each epochs training time : 81m 26s
#
#
# Epoch 93/100
# ----------
# train Loss: 0.01511 Acc: 100.00000 macro-f1: 1.00000
# vaild Loss: 0.25110 Acc: 92.75701 macro-f1: 0.91125
# each epochs training time : 82m 18s
#
#
# Epoch 94/100
# ----------
# train Loss: 0.01643 Acc: 99.93318 macro-f1: 0.99843
# vaild Loss: 0.24587 Acc: 93.06854 macro-f1: 0.91118
# each epochs training time : 83m 11s
#
#
# Epoch 95/100
# ----------
# train Loss: 0.01697 Acc: 99.96659 macro-f1: 0.99910
# vaild Loss: 0.24400 Acc: 92.91277 macro-f1: 0.91106
# each epochs training time : 84m 3s
#
#
# Epoch 96/100
# ----------
# train Loss: 0.01658 Acc: 99.89977 macro-f1: 0.99724
# vaild Loss: 0.24942 Acc: 93.14642 macro-f1: 0.91332
# ==> best model saved - 96 / 93.1
# each epochs training time : 84m 56s
#
#
# Epoch 97/100
# ----------
# train Loss: 0.01622 Acc: 100.00000 macro-f1: 1.00000
# vaild Loss: 0.25921 Acc: 92.28972 macro-f1: 0.90525
# each epochs training time : 85m 48s
#
#
# Epoch 98/100
# ----------
# train Loss: 0.01659 Acc: 100.00000 macro-f1: 1.00000
# vaild Loss: 0.25148 Acc: 92.52336 macro-f1: 0.90733
# each epochs training time : 86m 41s
#
#
# Epoch 99/100
# ----------
# train Loss: 0.01640 Acc: 99.96659 macro-f1: 0.99821
# vaild Loss: 0.25508 Acc: 92.91277 macro-f1: 0.90927
# each epochs training time : 87m 33s
#
#
# Training complete in 87m 34s
# Best valid Acc: 96 - 93.1
# model saved

# %%
## 모델을 평가 모드로 변경하고 test 데이터 분류
test_png = sorted(glob('/content/drive/MyDrive/dacon/dacon/open/test/*.png'))
test_imgs = [img_load(n) for n in tqdm(test_png)]
test_dataset = Custom_dataset_1(np.array(test_imgs), np.array(["tmp"]*len(test_imgs)), mode='test')
test_loader = DataLoader(test_dataset, shuffle=False, batch_size=batch_size)

model.eval()
f_pred = []

with torch.no_grad():
    for batch in (test_loader):
        x = torch.tensor(batch[0], dtype = torch.float32, device = device)
        with torch.cuda.amp.autocast():
            pred = model(x)
        f_pred.extend(pred.argmax(1).detach().cpu().numpy().tolist())
# Out:
# 100%|██████████| 2154/2154 [02:16<00:00, 15.81it/s]

# %%
torch.save(model.state_dict(), '/content/drive/MyDrive/dacon/dacon/model/EfficientNetV2_withsam_basic.pt')

# %%
## 숫자로된 레이블을 문자열 레이블로 변경
label_decoder = {value:key for key, value in label_unique.items()}
f_result = [label_decoder[result] for result in f_pred]

# %%
from datetime import datetime as dt 
today = dt.today().strftime('%Y-%m-%d')
version = f'efficientNetv2_rw_by_timm_imageTransfroms_ver_{today}'
submission = pd.read_csv(f"/content/drive/MyDrive/dacon/dacon/open/sample_submission.csv")

## 시각적 확인을 위해 문자열 레이블로 이루어진 된 label 필드 생성
submission["label"] = f_result
display(submission)
submission.to_csv(f"/content/drive/MyDrive/dacon/dacon/open/efficientv2_rw_sam0507_{version}_basic.csv", index = False)
# Out:
#       index             label
# 0         0   tile-glue_strip
# 1         1         grid-good
# 2         2   transistor-good
# 3         3        tile-rough
# 4         4         tile-good
# ...     ...               ...
# 2149   2149  tile-gray_stroke
# 2150   2150        screw-good
# 2151   2151         grid-good
# 2152   2152        cable-good
# 2153   2153       zipper-good
#
# [2154 rows x 2 columns]
