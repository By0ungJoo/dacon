# %% [markdown]
# <a href="https://colab.research.google.com/github/By0ungJoo/dacon/blob/main/efficientnetv2_rw_s_%EC%88%98%EC%A0%95.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install timm
import timm
model = timm.create_model('efficientnetv2_rw_s', pretrained=True, num_classes=88)
# Out:
# Collecting timm
#   Downloading timm-0.5.4-py3-none-any.whl (431 kB)
#      |████████████████████████████████| 431 kB 16.2 MB/s
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from timm) (0.12.0+cu113)
# Requirement already satisfied: torch>=1.4 in /usr/local/lib/python3.7/dist-packages (from timm) (1.11.0+cu113)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.4->timm) (4.2.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torchvision->timm) (2.23.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torchvision->timm) (1.21.6)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision->timm) (7.1.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision->timm) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision->timm) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision->timm) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision->timm) (1.24.3)
# Installing collected packages: timm
# Successfully installed timm-0.5.4
# Downloading: "https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-weights/efficientnet_v2s_ra2_288-a6477665.pth" to /root/.cache/torch/hub/checkpoints/efficientnet_v2s_ra2_288-a6477665.pth

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import warnings
warnings.filterwarnings('ignore')

import torch
from glob import glob
from tqdm import tqdm
import cv2
#import timm
from torch.utils.data import Dataset, DataLoader
from sklearn.metrics import f1_score, accuracy_score
import gc
import pandas as pd
import numpy as np
import json
from PIL import Image
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
from torchvision import transforms, datasets
import matplotlib.pyplot as plt
import time
import os
import copy
import random
from sklearn.model_selection import train_test_split
from torch.utils.data import Subset
from PIL import Image

# %%
## 기본 설정
device = torch.device('cuda')
batch_size  = 32
random_seed = 1234
img_size = 224
random.seed(random_seed)
torch.manual_seed(random_seed)

# %%
def img_load(path):
    img = cv2.imread(path)[:,:,::-1] # Return type:	numpy.ndarray / 기본적으로 BGR로 불러옴, RGB 변환함
    img = cv2.resize(img, (224, 224))
    return img

class Custom_dataset_3(Dataset): # 기본이미지 + 변형이미지 (train 시 2배 증량됨)
    def __init__(self, img_paths, labels, mode='train'):
        self.img_paths = img_paths
        self.labels = labels
        self.mode=mode
    def __len__(self):
        return len(self.img_paths)

    def __getitem__(self, idx):
        if self.mode=='train':
          if idx < 4277: # 변경 없는 이미지
            img = self.img_paths[idx]
            img = transforms.ToTensor()(img) # PIL or ndarray -> tensor
            img = transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])(img)
            label = self.labels[idx]
            return img, label

          else : # 랜덤 변경된 이미지 추가됨 
            img = self.img_paths[idx]
            img = Image.fromarray(img)
            #img = transforms.Resize((img_size, img_size))(img) # 처음 이미지 불러올때 resize 했으므로 생략
            #img = transforms.RandomCrop(img_size)(img)
            img = transforms.RandomRotation(90, expand=False)(img)
            img = transforms.RandomVerticalFlip()(img)
            img = transforms.RandomHorizontalFlip()(img)
            img = transforms.ToTensor()(img) # PIL or ndarray -> tensor
            img = transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])(img)
            label = self.labels[idx]# (원핫인코딩 안할거면 해당 코드만 필요)
            return img, label

        if self.mode=='test':
          img = self.img_paths[idx]
          img = transforms.ToTensor()(img)
          label = self.labels[idx]# (원핫인코딩 안할거면 해당 코드만 필요)
          img = transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])(img)
          return img, label

# %%
### 이미지 로드 및 전처리
# 이미지 경로
train_png = sorted(glob('/content/drive/MyDrive/dacon/dacon/open/train1/*.png'))
train_imgs = [img_load(m) for m in tqdm(train_png)]

#train_imgs = np.load('/content/drive/MyDrive/DACON_이상치 탐지 알고리즘 경진대회/train_imgs_224.npy')
train_y = pd.read_csv('/content/drive/MyDrive/dacon/dacon/open/train_df.csv')

train_labels = train_y["label"] # 레이블순서는 이미지 파일 순서대로임

label_unique = sorted(np.unique(train_labels))
label_unique = {key:value for key,value in zip(label_unique, range(len(label_unique)))} # 오름차순으로 레이블별로 숫자 부여(0부터 시작)

train_labels = [label_unique[k] for k in train_labels]

## 이미지 증량 시만 사용
train_imgs = train_imgs + train_imgs
train_labels = train_labels+train_labels

train_dataset = Custom_dataset_3(np.array(train_imgs), np.array(train_labels), mode='train')

### 데이터셋 분리 > 층화추출 & 테스터 데이터 비율 : 0.3, 시드 : 1234, 셔플 = True(default)
train_idx, vaild_idx = train_test_split(list(range(len(train_dataset))), stratify=train_labels, test_size=0.3, random_state=random_seed)

datasets = {} # 데이터셋을 담을 딕셔너리
datasets['train'] = Subset(train_dataset, train_idx)
datasets['vaild']  = Subset(train_dataset, vaild_idx)

## data loader 선언
dataloaders, batch_num = {}, {}
dataloaders['train'] = torch.utils.data.DataLoader(datasets['train'],
                                                  batch_size=batch_size, shuffle=True,
                                                  num_workers=0)
dataloaders['vaild']  = torch.utils.data.DataLoader(datasets['vaild'],
                                                    batch_size=batch_size, shuffle=False,
                                                    num_workers=0)
'''
데이터 변형 코드를 추가한 후 아래 오류코드가 나와
Caught TypeError in DataLoader worker process 0
DataLoader > num_workers 를 4 -> 0 로 낮춤
'''

batch_num['train'], batch_num['vaild'] = len(dataloaders['train']), len(dataloaders['vaild'])
print('batch_size : %d,  train/vaild(데이터셋개수/배치사이즈) : %d / %d' % (batch_size, batch_num['train'],batch_num['vaild']))
# Out:
# 100%|██████████| 4277/4277 [07:26<00:00,  9.58it/s]
# batch_size : 32,  train/vaild(데이터셋개수/배치사이즈) : 188 / 81

# %%
import gc
gc.collect()
torch.cuda.empty_cache()

### f1 스코어 함수 
def score_function(real, pred): # 라이브러리 > sklearn.metrics 
    score = f1_score(real, pred, average="macro")
    return score

def train_model(model, criterion, optimizer, scheduler, num_epochs=25):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0
    #train_loss, train_acc, valid_loss, valid_acc = [], [], [], []
    train_loss, train_acc, valid_loss, valid_acc, train_f1, valid_f1 = [], [], [], [], [], []
    
    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs))# - 1))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'vaild']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss, running_corrects, num_cnt = 0.0, 0, 0
            
            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device) # device = torch.device('cuda')
                labels = labels.to(device) # device = torch.device('cuda')

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
                num_cnt += len(labels)
            if phase == 'train':
                scheduler.step()
            
            epoch_loss = float(running_loss / num_cnt)
            epoch_acc  = float((running_corrects.double() / num_cnt).cpu()*100)
            f1 = score_function(labels.cpu().data, preds.cpu()) # score_function or f1_score

            if phase == 'train':
                train_loss.append(epoch_loss)
                train_acc.append(epoch_acc)
                train_f1.append(f1)
            else:
                valid_loss.append(epoch_loss)
                valid_acc.append(epoch_acc)
                valid_f1.append(f1)

            print('{} Loss: {:.5f} Acc: {:.5f} macro-f1: {:.5f}'.format(phase, epoch_loss, epoch_acc, f1))
           
            # deep copy the model(최적모델 저장)
            if phase == 'vaild' and epoch_acc > best_acc:
                best_idx = epoch
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())
#                 best_model_wts = copy.deepcopy(model.module.state_dict())
                print('==> best model saved - %d / %.1f'%(best_idx, best_acc))
        # 한 에포크마다 실행 시간 출력하기(누적 시간으로 출력됨)
        time_elapsed = time.time() - since
        print('each epochs training time : {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))
        print('\n')

        # 한 에포크마다 필요없는 메모리 지우기 : 지우기 효과는 아직 확인 못해봄
        try:      
          gc.collect() # cpu 비움
          torch.cuda.empty_cache() # gpu 비움
        except:
          pass
          
    ## 학습 마무리 후
    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))
    print('Best valid Acc: %d - %.1f' %(best_idx, best_acc))

    # load best model weights
    '''
    한 에포크 마다 저장된 최적의 모델 가중치로 조정 후 다음 에포크가 돌아감
    '''
    model.load_state_dict(best_model_wts)
    torch.save(model.state_dict(), '/content/drive/MyDrive/dacon/dacon/model/president_model.pt')
    print('model saved')
    return model, best_idx, best_acc, train_loss, train_acc, valid_loss, valid_acc, train_f1, valid_f1

# 설정
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")  # set gpu

model = model.to(device)

criterion = nn.CrossEntropyLoss()

optimizer_ft = optim.SGD(model.parameters(), 
                         lr = 0.05,
                         momentum=0.9,
                         weight_decay=1e-4)

lmbda = lambda epoch: 0.98739
exp_lr_scheduler = optim.lr_scheduler.MultiplicativeLR(optimizer_ft, lr_lambda=lmbda)

# 사전학습된 가중치와 모델을 가져와 데이터셋으로 추가 모델 학습
model, best_idx, best_acc, train_loss, train_acc, valid_loss, valid_acc, train_f1, valid_f1 = train_model(model, criterion, optimizer_ft, exp_lr_scheduler, num_epochs=100)
# Out:
# Epoch 0/100
# ----------
# train Loss: 0.94157 Acc: 82.92968 macro-f1: 1.00000
# vaild Loss: 0.55376 Acc: 87.65095 macro-f1: 0.71429
# ==> best model saved - 0 / 87.7
# each epochs training time : 1m 27s
#
#
# Epoch 1/100
# ----------
# train Loss: 0.47718 Acc: 88.82579 macro-f1: 1.00000
# vaild Loss: 0.41202 Acc: 89.91040 macro-f1: 1.00000
# ==> best model saved - 1 / 89.9
# each epochs training time : 2m 55s
#
#
# Epoch 2/100
# ----------
# train Loss: 0.36462 Acc: 90.69651 macro-f1: 1.00000
# vaild Loss: 0.34139 Acc: 91.35177 macro-f1: 1.00000
# ==> best model saved - 2 / 91.4
# each epochs training time : 4m 26s
#
#
# Epoch 3/100
# ----------
# train Loss: 0.31877 Acc: 91.56506 macro-f1: 1.00000
# vaild Loss: 0.35051 Acc: 91.50760 macro-f1: 1.00000
# ==> best model saved - 3 / 91.5
# each epochs training time : 5m 58s
#
#
# Epoch 4/100
# ----------
# train Loss: 0.25548 Acc: 93.33556 macro-f1: 0.50000
# vaild Loss: 0.31865 Acc: 92.59836 macro-f1: 1.00000
# ==> best model saved - 4 / 92.6
# each epochs training time : 7m 30s
#
#
# Epoch 5/100
# ----------
# train Loss: 0.22091 Acc: 94.13730 macro-f1: 1.00000
# vaild Loss: 0.28970 Acc: 91.70238 macro-f1: 1.00000
# each epochs training time : 9m 2s
#
#
# Epoch 6/100
# ----------
# train Loss: 0.18430 Acc: 94.98914 macro-f1: 1.00000
# vaild Loss: 0.21119 Acc: 94.11765 macro-f1: 1.00000
# ==> best model saved - 6 / 94.1
# each epochs training time : 10m 34s
#
#
# Epoch 7/100
# ----------
# train Loss: 0.17684 Acc: 95.03925 macro-f1: 1.00000
# vaild Loss: 0.24473 Acc: 94.00078 macro-f1: 1.00000
# each epochs training time : 12m 6s
#
#
# Epoch 8/100
# ----------
# train Loss: 0.13905 Acc: 96.05813 macro-f1: 0.50000
# vaild Loss: 0.20524 Acc: 94.62407 macro-f1: 1.00000
# ==> best model saved - 8 / 94.6
# each epochs training time : 13m 38s
#
#
# Epoch 9/100
# ----------
# train Loss: 0.14167 Acc: 95.84099 macro-f1: 0.50000
# vaild Loss: 0.22133 Acc: 94.35138 macro-f1: 1.00000
# each epochs training time : 15m 10s
#
#
# Epoch 10/100
# ----------
# train Loss: 0.13115 Acc: 96.22515 macro-f1: 1.00000
# vaild Loss: 0.17415 Acc: 95.48111 macro-f1: 1.00000
# ==> best model saved - 10 / 95.5
# each epochs training time : 16m 43s
#
#
# Epoch 11/100
# ----------
# train Loss: 0.09568 Acc: 97.29414 macro-f1: 1.00000
# vaild Loss: 0.16389 Acc: 95.48111 macro-f1: 1.00000
# each epochs training time : 18m 15s
#
#
# Epoch 12/100
# ----------
# train Loss: 0.09969 Acc: 96.99349 macro-f1: 1.00000
# vaild Loss: 0.17678 Acc: 95.67589 macro-f1: 1.00000
# ==> best model saved - 12 / 95.7
# each epochs training time : 19m 47s
#
#
# Epoch 13/100
# ----------
# train Loss: 0.09840 Acc: 97.12711 macro-f1: 1.00000
# vaild Loss: 0.16079 Acc: 95.71484 macro-f1: 1.00000
# ==> best model saved - 13 / 95.7
# each epochs training time : 21m 19s
#
#
# Epoch 14/100
# ----------
# train Loss: 0.08227 Acc: 97.59479 macro-f1: 1.00000
# vaild Loss: 0.18671 Acc: 95.52006 macro-f1: 1.00000
# each epochs training time : 22m 51s
#
#
# Epoch 15/100
# ----------
# train Loss: 0.06788 Acc: 97.96225 macro-f1: 1.00000
# vaild Loss: 0.13658 Acc: 96.06545 macro-f1: 1.00000
# ==> best model saved - 15 / 96.1
# each epochs training time : 24m 23s
#
#
# Epoch 16/100
# ----------
# train Loss: 0.05281 Acc: 98.63037 macro-f1: 1.00000
# vaild Loss: 0.15564 Acc: 96.33814 macro-f1: 0.71429
# ==> best model saved - 16 / 96.3
# each epochs training time : 25m 55s
#
#
# Epoch 17/100
# ----------
# train Loss: 0.06829 Acc: 97.91214 macro-f1: 1.00000
# vaild Loss: 0.15556 Acc: 96.68874 macro-f1: 1.00000
# ==> best model saved - 17 / 96.7
# each epochs training time : 27m 27s
#
#
# Epoch 18/100
# ----------
# train Loss: 0.06081 Acc: 98.24620 macro-f1: 0.50000
# vaild Loss: 0.25319 Acc: 94.66303 macro-f1: 1.00000
# each epochs training time : 28m 59s
#
#
# Epoch 19/100
# ----------
# train Loss: 0.06449 Acc: 98.19609 macro-f1: 1.00000
# vaild Loss: 0.14108 Acc: 96.68874 macro-f1: 1.00000
# each epochs training time : 30m 31s
#
#
# Epoch 20/100
# ----------
# train Loss: 0.05403 Acc: 98.48004 macro-f1: 0.50000
# vaild Loss: 0.13560 Acc: 96.61083 macro-f1: 1.00000
# each epochs training time : 32m 3s
#
#
# Epoch 21/100
# ----------
# train Loss: 0.04808 Acc: 98.53015 macro-f1: 1.00000
# vaild Loss: 0.12915 Acc: 96.57187 macro-f1: 1.00000
# each epochs training time : 33m 35s
#
#
# Epoch 22/100
# ----------
# train Loss: 0.04992 Acc: 98.61366 macro-f1: 0.00000
# vaild Loss: 0.13397 Acc: 96.88352 macro-f1: 0.71429
# ==> best model saved - 22 / 96.9
# each epochs training time : 35m 7s
#
#
# Epoch 23/100
# ----------
# train Loss: 0.04700 Acc: 98.59696 macro-f1: 0.50000
# vaild Loss: 0.16190 Acc: 95.83171 macro-f1: 1.00000
# each epochs training time : 36m 39s
#
#
# Epoch 24/100
# ----------
# train Loss: 0.05369 Acc: 98.53015 macro-f1: 0.20000
# vaild Loss: 0.14711 Acc: 96.33814 macro-f1: 1.00000
# each epochs training time : 38m 11s
#
#
# Epoch 25/100
# ----------
# train Loss: 0.05979 Acc: 98.34642 macro-f1: 0.50000
# vaild Loss: 0.17471 Acc: 95.36424 macro-f1: 1.00000
# each epochs training time : 39m 43s
#
#
# Epoch 26/100
# ----------
# train Loss: 0.05443 Acc: 98.58026 macro-f1: 1.00000
# vaild Loss: 0.12088 Acc: 96.76665 macro-f1: 1.00000
# each epochs training time : 41m 15s
#
#
# Epoch 27/100
# ----------
# train Loss: 0.05743 Acc: 98.48004 macro-f1: 1.00000
# vaild Loss: 0.12215 Acc: 97.00039 macro-f1: 1.00000
# ==> best model saved - 27 / 97.0
# each epochs training time : 42m 47s
#
#
# Epoch 28/100
# ----------
# train Loss: 0.04608 Acc: 98.59696 macro-f1: 0.50000
# vaild Loss: 0.15054 Acc: 96.18231 macro-f1: 1.00000
# each epochs training time : 44m 19s
#
#
# Epoch 29/100
# ----------
# train Loss: 0.04966 Acc: 98.56355 macro-f1: 0.50000
# vaild Loss: 0.12516 Acc: 96.76665 macro-f1: 1.00000
# each epochs training time : 45m 50s
#
#
# Epoch 30/100
# ----------
# train Loss: 0.07775 Acc: 98.02906 macro-f1: 0.50000
# vaild Loss: 0.12827 Acc: 96.57187 macro-f1: 1.00000
# each epochs training time : 47m 22s
#
#
# Epoch 31/100
# ----------
# train Loss: 0.06434 Acc: 98.22950 macro-f1: 1.00000
# vaild Loss: 0.12119 Acc: 96.80561 macro-f1: 1.00000
# each epochs training time : 48m 53s
#
#
# Epoch 32/100
# ----------
# train Loss: 0.04220 Acc: 98.91431 macro-f1: 1.00000
# vaild Loss: 0.13128 Acc: 96.84457 macro-f1: 1.00000
# each epochs training time : 50m 25s
#
#
# Epoch 33/100
# ----------
# train Loss: 0.03591 Acc: 98.94772 macro-f1: 1.00000
# vaild Loss: 0.09716 Acc: 97.38995 macro-f1: 1.00000
# ==> best model saved - 33 / 97.4
# each epochs training time : 51m 56s
#
#
# Epoch 34/100
# ----------
# train Loss: 0.03245 Acc: 99.13145 macro-f1: 0.50000
# vaild Loss: 0.13909 Acc: 96.64979 macro-f1: 1.00000
# each epochs training time : 53m 27s
#
#
# Epoch 35/100
# ----------
# train Loss: 0.04728 Acc: 98.73058 macro-f1: 1.00000
# vaild Loss: 0.11056 Acc: 96.88352 macro-f1: 1.00000
# each epochs training time : 54m 59s
#
#
# Epoch 36/100
# ----------
# train Loss: 0.03670 Acc: 98.86421 macro-f1: 1.00000
# vaild Loss: 0.11778 Acc: 97.19517 macro-f1: 1.00000
# each epochs training time : 56m 30s
#
#
# Epoch 37/100
# ----------
# train Loss: 0.03727 Acc: 98.98113 macro-f1: 0.55556
# vaild Loss: 0.14069 Acc: 96.41605 macro-f1: 1.00000
# each epochs training time : 58m 1s
#
#
# Epoch 38/100
# ----------
# train Loss: 0.02903 Acc: 99.26507 macro-f1: 0.50000
# vaild Loss: 0.11964 Acc: 97.07830 macro-f1: 1.00000
# each epochs training time : 59m 33s
#
#
# Epoch 39/100
# ----------
# train Loss: 0.03548 Acc: 98.98113 macro-f1: 0.50000
# vaild Loss: 0.10421 Acc: 97.00039 macro-f1: 1.00000
# each epochs training time : 61m 4s
#
#
# Epoch 40/100
# ----------
# train Loss: 0.03750 Acc: 98.81410 macro-f1: 1.00000
# vaild Loss: 0.11415 Acc: 97.27308 macro-f1: 1.00000
# each epochs training time : 62m 35s
#
#
# Epoch 41/100
# ----------
# train Loss: 0.03216 Acc: 99.16486 macro-f1: 0.50000
# vaild Loss: 0.10994 Acc: 97.62369 macro-f1: 1.00000
# ==> best model saved - 41 / 97.6
# each epochs training time : 64m 6s
#
#
# Epoch 42/100
# ----------
# train Loss: 0.03142 Acc: 99.21497 macro-f1: 0.25000
# vaild Loss: 0.14117 Acc: 96.37709 macro-f1: 1.00000
# each epochs training time : 65m 38s
#
#
# Epoch 43/100
# ----------
# train Loss: 0.03518 Acc: 99.01453 macro-f1: 0.50000
# vaild Loss: 0.10343 Acc: 97.62369 macro-f1: 1.00000
# each epochs training time : 67m 9s
#
#
# Epoch 44/100
# ----------
# train Loss: 0.02206 Acc: 99.36529 macro-f1: 1.00000
# vaild Loss: 0.10498 Acc: 97.62369 macro-f1: 1.00000
# each epochs training time : 68m 41s
#
#
# Epoch 45/100
# ----------
# train Loss: 0.02316 Acc: 99.24837 macro-f1: 1.00000
# vaild Loss: 0.09640 Acc: 97.54577 macro-f1: 1.00000
# each epochs training time : 70m 13s
#
#
# Epoch 46/100
# ----------
# train Loss: 0.02583 Acc: 99.24837 macro-f1: 1.00000
# vaild Loss: 0.10341 Acc: 97.31204 macro-f1: 1.00000
# each epochs training time : 71m 45s
#
#
# Epoch 47/100
# ----------
# train Loss: 0.03219 Acc: 99.19826 macro-f1: 0.25000
# vaild Loss: 0.09384 Acc: 97.62369 macro-f1: 1.00000
# each epochs training time : 73m 17s
#
#
# Epoch 48/100
# ----------
# train Loss: 0.01806 Acc: 99.49891 macro-f1: 1.00000
# vaild Loss: 0.09877 Acc: 97.74055 macro-f1: 1.00000
# ==> best model saved - 48 / 97.7
# each epochs training time : 74m 49s
#
#
# Epoch 49/100
# ----------
# train Loss: 0.01705 Acc: 99.58243 macro-f1: 1.00000
# vaild Loss: 0.12145 Acc: 97.23413 macro-f1: 1.00000
# each epochs training time : 76m 21s
#
#
# Epoch 50/100
# ----------
# train Loss: 0.02134 Acc: 99.41540 macro-f1: 1.00000
# vaild Loss: 0.12378 Acc: 97.11726 macro-f1: 1.00000
# each epochs training time : 77m 52s
#
#
# Epoch 51/100
# ----------
# train Loss: 0.03063 Acc: 99.13145 macro-f1: 1.00000
# vaild Loss: 0.10704 Acc: 97.58473 macro-f1: 1.00000
# each epochs training time : 79m 24s
#
#
# Epoch 52/100
# ----------
# train Loss: 0.01613 Acc: 99.58243 macro-f1: 0.55556
# vaild Loss: 0.10694 Acc: 97.93533 macro-f1: 1.00000
# ==> best model saved - 52 / 97.9
# each epochs training time : 80m 57s
#
#
# Epoch 53/100
# ----------
# train Loss: 0.02866 Acc: 99.24837 macro-f1: 0.50000
# vaild Loss: 0.08551 Acc: 97.81847 macro-f1: 1.00000
# each epochs training time : 82m 28s
#
#
# Epoch 54/100
# ----------
# train Loss: 0.02027 Acc: 99.36529 macro-f1: 1.00000
# vaild Loss: 0.08901 Acc: 97.74055 macro-f1: 1.00000
# each epochs training time : 83m 60s
#
#
# Epoch 55/100
# ----------
# train Loss: 0.01679 Acc: 99.54902 macro-f1: 0.55556
# vaild Loss: 0.08564 Acc: 97.97429 macro-f1: 1.00000
# ==> best model saved - 55 / 98.0
# each epochs training time : 85m 32s
#
#
# Epoch 56/100
# ----------
# train Loss: 0.01740 Acc: 99.51562 macro-f1: 1.00000
# vaild Loss: 0.08617 Acc: 98.01325 macro-f1: 1.00000
# ==> best model saved - 56 / 98.0
# each epochs training time : 87m 3s
#
#
# Epoch 57/100
# ----------
# train Loss: 0.01978 Acc: 99.44881 macro-f1: 0.55556
# vaild Loss: 0.07516 Acc: 98.05220 macro-f1: 1.00000
# ==> best model saved - 57 / 98.1
# each epochs training time : 88m 35s
#
#
# Epoch 58/100
# ----------
# train Loss: 0.01633 Acc: 99.49891 macro-f1: 1.00000
# vaild Loss: 0.08358 Acc: 97.93533 macro-f1: 1.00000
# each epochs training time : 90m 6s
#
#
# Epoch 59/100
# ----------
# train Loss: 0.01501 Acc: 99.59913 macro-f1: 1.00000
# vaild Loss: 0.07947 Acc: 98.01325 macro-f1: 1.00000
# each epochs training time : 91m 38s
#
#
# Epoch 60/100
# ----------
# train Loss: 0.01668 Acc: 99.54902 macro-f1: 0.50000
# vaild Loss: 0.08921 Acc: 97.77951 macro-f1: 1.00000
# each epochs training time : 93m 9s
#
#
# Epoch 61/100
# ----------
# train Loss: 0.01775 Acc: 99.58243 macro-f1: 1.00000
# vaild Loss: 0.08175 Acc: 97.85742 macro-f1: 1.00000
# each epochs training time : 94m 41s
#
#
# Epoch 62/100
# ----------
# train Loss: 0.01908 Acc: 99.44881 macro-f1: 1.00000
# vaild Loss: 0.08591 Acc: 97.77951 macro-f1: 1.00000
# each epochs training time : 96m 13s
#
#
# Epoch 63/100
# ----------
# train Loss: 0.02180 Acc: 99.39870 macro-f1: 1.00000
# vaild Loss: 0.08980 Acc: 97.85742 macro-f1: 1.00000
# each epochs training time : 97m 44s
#
#
# Epoch 64/100
# ----------
# train Loss: 0.01124 Acc: 99.69935 macro-f1: 1.00000
# vaild Loss: 0.07946 Acc: 98.13011 macro-f1: 1.00000
# ==> best model saved - 64 / 98.1
# each epochs training time : 99m 16s
#
#
# Epoch 65/100
# ----------
# train Loss: 0.01233 Acc: 99.59913 macro-f1: 0.25000
# vaild Loss: 0.09987 Acc: 97.66264 macro-f1: 1.00000
# each epochs training time : 100m 47s
#
#
# Epoch 66/100
# ----------
# train Loss: 0.01528 Acc: 99.56573 macro-f1: 0.16667
# vaild Loss: 0.08669 Acc: 97.74055 macro-f1: 1.00000
# each epochs training time : 102m 19s
#
#
# Epoch 67/100
# ----------
# train Loss: 0.02449 Acc: 99.33189 macro-f1: 1.00000
# vaild Loss: 0.09666 Acc: 97.62369 macro-f1: 1.00000
# each epochs training time : 103m 51s
#
#
# Epoch 68/100
# ----------
# train Loss: 0.02187 Acc: 99.39870 macro-f1: 1.00000
# vaild Loss: 0.09916 Acc: 97.70160 macro-f1: 1.00000
# each epochs training time : 105m 22s
#
#
# Epoch 69/100
# ----------
# train Loss: 0.01362 Acc: 99.73275 macro-f1: 1.00000
# vaild Loss: 0.07124 Acc: 98.24698 macro-f1: 1.00000
# ==> best model saved - 69 / 98.2
# each epochs training time : 106m 54s
#
#
# Epoch 70/100
# ----------
# train Loss: 0.01125 Acc: 99.61583 macro-f1: 1.00000
# vaild Loss: 0.09385 Acc: 97.85742 macro-f1: 1.00000
# each epochs training time : 108m 26s
#
#
# Epoch 71/100
# ----------
# train Loss: 0.01193 Acc: 99.64924 macro-f1: 1.00000
# vaild Loss: 0.08792 Acc: 98.01325 macro-f1: 1.00000
# each epochs training time : 109m 57s
#
#
# Epoch 72/100
# ----------
# train Loss: 0.01157 Acc: 99.74946 macro-f1: 1.00000
# vaild Loss: 0.09585 Acc: 97.74055 macro-f1: 1.00000
# each epochs training time : 111m 29s
#
#
# Epoch 73/100
# ----------
# train Loss: 0.01196 Acc: 99.68265 macro-f1: 0.50000
# vaild Loss: 0.08083 Acc: 98.20802 macro-f1: 1.00000
# each epochs training time : 113m 1s
#
#
# Epoch 74/100
# ----------
# train Loss: 0.01767 Acc: 99.48221 macro-f1: 1.00000
# vaild Loss: 0.09230 Acc: 97.77951 macro-f1: 1.00000
# each epochs training time : 114m 33s
#
#
# Epoch 75/100
# ----------
# train Loss: 0.01517 Acc: 99.64924 macro-f1: 1.00000
# vaild Loss: 0.08995 Acc: 97.97429 macro-f1: 1.00000
# each epochs training time : 116m 5s
#
#
# Epoch 76/100
# ----------
# train Loss: 0.00892 Acc: 99.79957 macro-f1: 1.00000
# vaild Loss: 0.08336 Acc: 97.81847 macro-f1: 1.00000
# each epochs training time : 117m 37s
#
#
# Epoch 77/100
# ----------
# train Loss: 0.01370 Acc: 99.58243 macro-f1: 1.00000
# vaild Loss: 0.11102 Acc: 97.19517 macro-f1: 1.00000
# each epochs training time : 119m 9s
#
#
# Epoch 78/100
# ----------
# train Loss: 0.01069 Acc: 99.73275 macro-f1: 1.00000
# vaild Loss: 0.09029 Acc: 97.81847 macro-f1: 1.00000
# each epochs training time : 120m 40s
#
#
# Epoch 79/100
# ----------
# train Loss: 0.01136 Acc: 99.66594 macro-f1: 1.00000
# vaild Loss: 0.09008 Acc: 97.70160 macro-f1: 1.00000
# each epochs training time : 122m 12s
#
#
# Epoch 80/100
# ----------
# train Loss: 0.01090 Acc: 99.69935 macro-f1: 0.50000
# vaild Loss: 0.08920 Acc: 98.05220 macro-f1: 1.00000
# each epochs training time : 123m 44s
#
#
# Epoch 81/100
# ----------
# train Loss: 0.00956 Acc: 99.74946 macro-f1: 1.00000
# vaild Loss: 0.06642 Acc: 98.32489 macro-f1: 1.00000
# ==> best model saved - 81 / 98.3
# each epochs training time : 125m 16s
#
#
# Epoch 82/100
# ----------
# train Loss: 0.00628 Acc: 99.84967 macro-f1: 1.00000
# vaild Loss: 0.07058 Acc: 98.32489 macro-f1: 1.00000
# each epochs training time : 126m 47s
#
#
# Epoch 83/100
# ----------
# train Loss: 0.00474 Acc: 99.89978 macro-f1: 1.00000
# vaild Loss: 0.08210 Acc: 98.24698 macro-f1: 1.00000
# each epochs training time : 128m 19s
#
#
# Epoch 84/100
# ----------
# train Loss: 0.00577 Acc: 99.89978 macro-f1: 1.00000
# vaild Loss: 0.10168 Acc: 97.62369 macro-f1: 1.00000
# each epochs training time : 129m 51s
#
#
# Epoch 85/100
# ----------
# train Loss: 0.01180 Acc: 99.61583 macro-f1: 1.00000
# vaild Loss: 0.08564 Acc: 97.97429 macro-f1: 1.00000
# each epochs training time : 131m 23s
#
#
# Epoch 86/100
# ----------
# train Loss: 0.01059 Acc: 99.78286 macro-f1: 0.50000
# vaild Loss: 0.07258 Acc: 98.28594 macro-f1: 1.00000
# each epochs training time : 132m 54s
#
#
# Epoch 87/100
# ----------
# train Loss: 0.00917 Acc: 99.74946 macro-f1: 1.00000
# vaild Loss: 0.07396 Acc: 98.32489 macro-f1: 1.00000
# each epochs training time : 134m 26s
#
#
# Epoch 88/100
# ----------
# train Loss: 0.01282 Acc: 99.66594 macro-f1: 0.50000
# vaild Loss: 0.09482 Acc: 97.70160 macro-f1: 1.00000
# each epochs training time : 135m 58s
#
#
# Epoch 89/100
# ----------
# train Loss: 0.01542 Acc: 99.51562 macro-f1: 1.00000
# vaild Loss: 0.08355 Acc: 98.28594 macro-f1: 1.00000
# each epochs training time : 137m 30s
#
#
# Epoch 90/100
# ----------
# train Loss: 0.00775 Acc: 99.78286 macro-f1: 0.50000
# vaild Loss: 0.08379 Acc: 98.28594 macro-f1: 1.00000
# each epochs training time : 139m 1s
#
#
# Epoch 91/100
# ----------
# train Loss: 0.00792 Acc: 99.81627 macro-f1: 1.00000
# vaild Loss: 0.07808 Acc: 98.13011 macro-f1: 1.00000
# each epochs training time : 140m 33s
#
#
# Epoch 92/100
# ----------
# train Loss: 0.00558 Acc: 99.86638 macro-f1: 0.50000
# vaild Loss: 0.07074 Acc: 98.44176 macro-f1: 1.00000
# ==> best model saved - 92 / 98.4
# each epochs training time : 142m 5s
#
#
# Epoch 93/100
# ----------
# train Loss: 0.00609 Acc: 99.88308 macro-f1: 0.33333
# vaild Loss: 0.08124 Acc: 98.44176 macro-f1: 1.00000
# each epochs training time : 143m 36s
#
#
# Epoch 94/100
# ----------
# train Loss: 0.00938 Acc: 99.79957 macro-f1: 1.00000
# vaild Loss: 0.07600 Acc: 98.59758 macro-f1: 1.00000
# ==> best model saved - 94 / 98.6
# each epochs training time : 145m 8s
#
#
# Epoch 95/100
# ----------
# train Loss: 0.00660 Acc: 99.84967 macro-f1: 1.00000
# vaild Loss: 0.09999 Acc: 97.81847 macro-f1: 1.00000
# each epochs training time : 146m 40s
#
#
# Epoch 96/100
# ----------
# train Loss: 0.00546 Acc: 99.88308 macro-f1: 1.00000
# vaild Loss: 0.14810 Acc: 97.42891 macro-f1: 1.00000
# each epochs training time : 148m 11s
#
#
# Epoch 97/100
# ----------
# train Loss: 0.00686 Acc: 99.81627 macro-f1: 0.55556
# vaild Loss: 0.07730 Acc: 98.28594 macro-f1: 1.00000
# each epochs training time : 149m 43s
#
#
# Epoch 98/100
# ----------
# train Loss: 0.00736 Acc: 99.86638 macro-f1: 1.00000
# vaild Loss: 0.08514 Acc: 98.01325 macro-f1: 1.00000
# each epochs training time : 151m 14s
#
#
# Epoch 99/100
# ----------
# train Loss: 0.00724 Acc: 99.81627 macro-f1: 0.50000
# vaild Loss: 0.07178 Acc: 98.48072 macro-f1: 1.00000
# each epochs training time : 152m 46s
#
#
# Training complete in 152m 46s
# Best valid Acc: 94 - 98.6
# model saved

# %%
## 모델을 평가 모드로 변경하고 test 데이터 분류
test_png = sorted(glob('/content/drive/MyDrive/dacon/dacon/open/test/*.png'))
test_imgs = [img_load(n) for n in tqdm(test_png)]
test_dataset = Custom_dataset_3(np.array(test_imgs), np.array(["tmp"]*len(test_imgs)), mode='test')
test_loader = DataLoader(test_dataset, shuffle=False, batch_size=batch_size)

model.eval()
f_pred = []

with torch.no_grad():
    for batch in (test_loader):
        x = torch.tensor(batch[0], dtype = torch.float32, device = device)
        with torch.cuda.amp.autocast():
            pred = model(x)
        f_pred.extend(pred.argmax(1).detach().cpu().numpy().tolist())
# Out:
# 100%|██████████| 2154/2154 [01:07<00:00, 31.85it/s]

# %%
torch.save(model.state_dict(), '/content/drive/MyDrive/dacon/dacon/model/EfficientNetV2.pt')

# %%
## 숫자로된 레이블을 문자열 레이블로 변경
label_decoder = {value:key for key, value in label_unique.items()}
f_result = [label_decoder[result] for result in f_pred]

# %%
from datetime import datetime as dt 
today = dt.today().strftime('%Y-%m-%d')
version = f'efficientNetv2_rw_by_timm_imageTransfroms_ver_{today}'
submission = pd.read_csv(f"/content/drive/MyDrive/dacon/dacon/open/sample_submission.csv")

## 시각적 확인을 위해 문자열 레이블로 이루어진 된 label 필드 생성
submission["label"] = f_result
display(submission)
submission.to_csv(f"/content/drive/MyDrive/dacon/dacon/open/sample_submission_efficientv2_rw1_{version}.csv", index = False)
# Out:
#       index             label
# 0         0   tile-glue_strip
# 1         1         grid-good
# 2         2   transistor-good
# 3         3  tile-gray_stroke
# 4         4         tile-good
# ...     ...               ...
# 2149   2149  tile-gray_stroke
# 2150   2150        screw-good
# 2151   2151         grid-good
# 2152   2152        cable-good
# 2153   2153       zipper-good
#
# [2154 rows x 2 columns]
